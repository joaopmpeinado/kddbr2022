# %%
import os
import pandas as pd
import numpy as np
import catboost as cat
from lightgbm.callback import early_stopping
from sklearn.model_selection import KFold, GroupKFold
from tqdm import tqdm
from sklearn.metrics import mean_squared_error
import warnings

import math
# Out:
# <style type='text/css'>
# .datatable table.frame { margin-bottom: 0; }
# .datatable table.frame thead { border-bottom: none; }
# .datatable table.frame tr.coltypes td {  color: #FFFFFF;  line-height: 6px;  padding: 0 0.5em;}
# .datatable .bool    { background: #DDDD99; }
# .datatable .object  { background: #565656; }
# .datatable .int     { background: #5D9E5D; }
# .datatable .float   { background: #4040CC; }
# .datatable .str     { background: #CC4040; }
# .datatable .time    { background: #40CC40; }
# .datatable .row_index {  background: var(--jp-border-color3);  border-right: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  font-size: 9px;}
# .datatable .frame tbody td { text-align: left; }
# .datatable .frame tr.coltypes .row_index {  background: var(--jp-border-color0);}
# .datatable th:nth-child(2) { padding-left: 12px; }
# .datatable .hellipsis {  color: var(--jp-cell-editor-border-color);}
# .datatable .vellipsis {  background: var(--jp-layout-color0);  color: var(--jp-cell-editor-border-color);}
# .datatable .na {  color: var(--jp-cell-editor-border-color);  font-size: 80%;}
# .datatable .sp {  opacity: 0.25;}
# .datatable .footer { font-size: 9px; }
# .datatable .frame_dimensions {  background: var(--jp-border-color3);  border-top: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  display: inline-block;  opacity: 0.6;  padding: 1px 10px 1px 5px;}
# </style>

# %%
pd.set_option('display.width', 1000)
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
warnings.filterwarnings('ignore')

path = os.getcwd()

# %%
train = pd.read_csv('../input/kddbr2022apk/train_sequence_fold.csv')
test = pd.read_csv('../input/kddbr2022apk/test_sequence.csv')
df = pd.concat([train, test])

features_1 = pd.read_csv('../input/kddbr2022apk/complete_04.csv')
features_1 = features_1[["Filename","w_std","w_mean","w_median","w_min","w_max","w_var","n_std","n_mean","n_median","n_min","n_max","n_var","d_std","d_mean","d_median","d_min","d_max","d_var"]]
features_1.columns = ["Filename","_w_std","_w_mean","_w_median","_w_min","_w_max","_w_var","_n_std","_n_mean","_n_median","_n_min","_n_max","_n_var","_d_std","_d_mean","_d_median","_d_min","_d_max","_d_var"]
features_2 = pd.read_csv('../input/kddbr2022apk/complete_05.csv')
features_3 = pd.read_csv('../input/kddbr2022apk/complete_06.csv')
features_4 = pd.read_csv('../input/kddbr2022apk/complete_12.csv')

features = pd.merge(features_1, features_2, on='Filename', how='left')
features = pd.merge(features, features_3, on='Filename', how='left')


mario_features_tr = pd.read_csv('../input/kddbr2022apk/mario_train_vec_v1.csv')
mario_features_ts = pd.read_csv('../input/kddbr2022apk/mario_test_vec_v1.csv')

mario_features = pd.concat([mario_features_tr, mario_features_ts])
mario_features2 = pd.read_csv('../input/kddbr2022apk/vecs_v3_fe.csv')

# %%
df = pd.merge(df, features, on='Filename', how='left')
df = pd.merge(df, mario_features, on='Filename', how='left')
df = pd.merge(df, mario_features2, on='Filename', how='left')
df = pd.merge(df, features_4, on='Filename', how='left')

df = df.sort_values(by=['run_id','run_seq_id'], ascending=False).reset_index(drop=True)

# %%
import gc
del features, mario_features, mario_features2, features_4, features_2, features_3, features_1
gc.collect()
# Out:
# 21

# %%
df
# Out:
#                                     Filename    Altitude     Delta     North      East  run_id  run_seq_id  fold    _w_std   _w_mean  _w_median  _w_min  _w_max     _w_var    _n_std   _n_mean  _n_median  _n_min  _n_max     _n_var      _d_std     _d_mean   _d_median      _d_min       _d_max        _d_var  base_05_f05_W_0  base_05_f05_W_3  base_05_f05_W_6  base_05_f05_W_9  base_05_f05_W_12  base_05_f05_W_15  base_05_f05_W_18  base_05_f05_W_21  base_05_f05_W_24  base_05_w_std  base_05_w_mean  base_05_w_median  base_05_w_min  base_05_w_max  base_05_w_var  base_05_f05_H_1  base_05_f05_H_4  base_05_f05_H_7  base_05_f05_H_10  base_05_f05_H_13  base_05_f05_H_16  base_05_f05_H_19  base_05_f05_H_22  base_05_f05_H_25  base_05_n_std  base_05_n_mean  base_05_n_median  base_05_n_min  base_05_n_max  base_05_n_var  base_05_f05_D_2  base_05_f05_D_5  base_05_f05_D_8  base_05_f05_D_11  base_05_f05_D_14  base_05_f05_D_17  base_05_f05_D_20  base_05_f05_D_23  base_05_f05_D_26  base_05_d_std  \
# 146259   5.066331  113.592926   64.338103  32.636659    6.824354  115.372246  130.638716  48.378531   33.496269  250.926285  354.061202  28.940873  250.059998  435.912842  -0.078176  0.252735  -0.932037   1.116669  -0.079773  0.219259  -0.731680   0.687408     0.123536    0.196720     0.002400     1.253522      0.370513     0.137355     0.090516     0.691285      1.003165     0.010746     0.958596     1.085381      1.001831     0.007525     0.980152     1.052619        0.0        0.0        116.649046             0.977211                0.0                 0.0
# 146260   5.498898  114.060135   63.638628  34.022613    6.688907  115.487061  121.632213  47.234039   33.823071  273.285553  352.469110  31.733437  198.275055  431.431335   0.011441  0.237558  -0.810181   0.585356   0.055474  0.217827  -0.716896   1.248504     0.106338    0.191694     0.000041     1.601327      0.346368     0.132097     0.093312     0.693641      0.999555     0.012610     0.918906     1.068422      0.997652     0.014428     0.848969     1.043538        0.0        0.0        114.973910             0.977934                0.0                 0.0
# 146261   5.052969  114.559151   64.553544  32.357292    6.649139  115.522118   97.883220  46.533326   17.972200  253.980316  351.563958  28.867455  228.089890  431.692017  -0.430007  6.184491 -79.838287   0.762772   0.027265  0.217390  -0.466999   2.128319    38.251521  493.592889     0.000243  6378.681868      0.279151     0.132511     0.053910     0.675463      1.018325     0.247193     0.960346     4.193015      0.999741     0.005402     0.966782     1.023672        0.0        0.0        108.383578             0.979622                0.0                 0.0
#
# [146262 rows x 174 columns]

# %%
df['sqrt_altitude'] = np.sqrt(df['Altitude'])
df['sqrt_delta'] = np.sqrt(df['Delta'])
df['sqrt_altitude_delta'] = np.sqrt(df['Altitude'] + df['Delta'])

df['pow2_altitude'] = (df['Altitude'] ** 2)
df['pow2_delta'] = (df['Delta'] ** 2)
df['pow2_altitude_delta'] = (df['Altitude'] + df['Delta']) ** 2

df['log_Altitude'] = np.log(df['Altitude'])
df['log_Delta'] = np.log(df['Delta'])
df['log_base_05_n_mean'] = np.log(df['base_05_n_mean'])

df['pow13_Altitude'] = df['Altitude'] ** (1/3)
df['pow13_Delta'] = df['Delta'] ** (1/3)
df['pow13_base_05_n_mean'] = df['base_05_n_mean'] ** (1/3)

tgt_columns = [
    'Delta', 'Altitude', 'log_base_05_n_mean', 'pow13_base_05_n_mean',
    'base_05_n_mean', '_n_mean', 'base_05_f05_H_1', 'base_05_n_median', 'base_05_n_max', 'base_05_n_min', 'base_05_f05_H_4', 'x', 'base_05_f05_H_25', 'base_05_f05_H_7', 'x_mean', 'x1_mean', 'x2_mean',
    'base_05_w_mean', '_w_mean', 'base_05_f05_W_21', 'base_05_w_median', 'base_05_w_max', 'base_05_w_min', 'base_05_f05_W_18', 'y', 'base_05_f05_W_6', 'base_05_f05_W_0', 'y_mean', 'y1_mean', 'y2_mean',
    'base_06_n_mean', 'base_06_f06_H_1', 'base_06_n_median', 'base_06_n_max',
    'base_06_w_mean', 'base_06_f06_W_21', 'base_06_w_median', 'base_06_w_max',
    'base_12_x', 'base_12_y', 'base_12_distance'
]

seq_win = [2,3,5,10,15,25,30,50,75]
nxt_sft_win = [1,2,3,4,5,8,10,12,15,20]

for col in tqdm(tgt_columns):
    for win in nxt_sft_win:
        df['shift'+str(win)+'_'+col] = df.groupby('run_id')[col].shift(win).reset_index(0,drop=True)
#         df['next'+str(win)+'_'+col] = df.groupby('run_id')[col].shift(-win).reset_index(0,drop=True)
        df['seq_diff_last'+str(win)+'_'+col] = df.groupby('run_id')[col].diff(win).reset_index(0,drop=True)
#         df['seq_diff_next'+str(win)+'_'+col] = df.groupby('run_id')[col].diff(-win).reset_index(0,drop=True)
        df['seq_div_last'+str(win)+'_'+col] = df[col] / df['shift'+str(win)+'_'+col]
    
    for win in seq_win:
        df['seq_avg_w'+str(win)+'_'+col] = df.groupby('run_id')[col].rolling(win).mean().reset_index(0,drop=True)
        df['seq_std_w'+str(win)+'_'+col] = df.groupby('run_id')[col].rolling(win).std().reset_index(0,drop=True)
        df['seq_max_w'+str(win)+'_'+col] = df.groupby('run_id')[col].rolling(win).max().reset_index(0,drop=True)
        df['seq_min_w'+str(win)+'_'+col] = df.groupby('run_id')[col].rolling(win).min().reset_index(0,drop=True)
    
    
#     df['seq_div_last1_'+col] = df[col] / df['shift1_'+col]
#     df['seq_div_next1_'+col] = df[col] / df['next1_'+col]
#     df['seq_div_last2_'+col] = df[col] / df['shift2_'+col]
#     df['seq_div_next2_'+col] = df[col] / df['next2_'+col]
#     df['seq_div_last3_'+col] = df[col] / df['shift3_'+col]
#     df['seq_div_next3_'+col] = df[col] / df['next3_'+col]
    
    df['seq_min_'+col] = df.groupby('run_id')[col].transform('min')
    df['seq_max_'+col] = df.groupby('run_id')[col].transform('max')
    df['seq_std_'+col] = df.groupby('run_id')[col].transform('std')
    df['seq_avg_'+col] = df.groupby('run_id')[col].transform('mean')

# df['r_vetorial_now'] = (df['base_05_n_mean'] ** 2) + (df['base_05_w_mean'] ** 2)
# df['shift_r_vetorial'] = (df['shift1_base_05_n_mean'] ** 2) + (df['shift1_base_05_w_mean'] ** 2)
# df['shift2_r_vetorial'] = (df['shift2_base_05_n_mean'] ** 2) + (df['shift2_base_05_w_mean'] ** 2)
# df['next_r_vetorial'] = (df['next1_base_05_n_mean'] ** 2) + (df['next1_base_05_w_mean'] ** 2)
# df['next2_r_vetorial'] = (df['next2_base_05_n_mean'] ** 2) + (df['next2_base_05_w_mean'] ** 2)
# df['avg_shift_r_vet'] = (df['r_vetorial_now'] + df['shift_r_vetorial'] + df['shift2_r_vetorial']) / 3
# df['avg_next_r_vet'] = (df['r_vetorial_now'] + df['next_r_vetorial'] + df['next2_r_vetorial']) / 3
# df['avg_all_r_vet'] = (df['r_vetorial_now'] + df['next_r_vetorial'] + df['next2_r_vetorial'] + df['shift_r_vetorial'] + df['shift2_r_vetorial']) / 5

# df['div_r_next2_next'] = df['next2_r_vetorial'] / df['next_r_vetorial']
# df['div_r_next_now'] = df['next_r_vetorial'] / df['r_vetorial_now']
# df['div_r_now_shift'] = df['r_vetorial_now'] / df['shift_r_vetorial']
# df['div_r_shift1_shift2'] = df['shift_r_vetorial'] / df['shift2_r_vetorial']
# df['avg_div_r'] = (df['div_r_next2_next'] + df['div_r_next_now'] + df['div_r_now_shift'] + df['div_r_shift1_shift2']) / 4
# Out:
# 100%|██████████| 41/41 [04:38<00:00,  6.79s/it]

# %%
print(df.shape)
# Out:
# (146262, 3056)

# %%
train = df.loc[~df.North.isnull(), :].sort_values(by=['run_id', 'run_seq_id']).reset_index(drop=True)
test = df.loc[df.North.isnull(), :].sort_values(by=['run_id', 'run_seq_id']).reset_index(drop=True)

# %%
import gc
del df
gc.collect()
# Out:
# 21

# %%
train_columns = [col for col in train.columns if col not in ['Filename', 'North', 'East', 'fold', 'run_id', 'run_seq_id']]

# %%
n_folds = 5

north_oof_preds = np.zeros(len(train))
east_oof_preds = np.zeros(len(train))

north_test_preds = np.zeros(len(test))
east_test_preds = np.zeros(len(test))

targets = ['North', 'East']

# %%
train = train.replace([np.inf, -np.inf], np.nan)
#trn_x = trn_x.fillna(-999)
test = test.replace([np.inf, -np.inf], np.nan)

# %%
# %%time
for target in targets:
    y = train[target]
    oof_preds = np.zeros(len(train))
    test_preds_fold = np.zeros(len(test))
    score_folds  = []

    # folds = GroupKFold(n_splits=n_folds)
    # for fold_, (trn_, val_) in enumerate(folds.split(y, y, train.run_id)):
    for fold_ in train.fold.sort_values().unique():
        print("Fold: {}".format(fold_))

        trn_ = train.loc[train.fold != fold_].index
        val_ = train.loc[train.fold == fold_].index

        trn_x, trn_y = train.loc[trn_, train_columns], y.loc[trn_]
        val_x, val_y = train.loc[val_, train_columns], y.loc[val_]

        dtrain = cat.Pool(trn_x, trn_y)
        dvalid = cat.Pool(val_x, val_y)
        
        params = {
            'loss_function':       'RMSE',
            'eval_metric':         'RMSE',
            'bootstrap_type': 'Bernoulli', 
            'learning_rate':         0.05,
            #'subsample':              0.9,
            'depth':                   10,
            #'min_data_in_leaf':        50,
            'verbose':               200,
            'task_type':            'GPU',
            'random_seed':             144
        }
        
        execs = 1
        preds = np.zeros(len(val_x))
        test_preds_exec = np.zeros(len(test))
        
        for p in range(0,execs):
            print("Iteration: {}".format(p+1))
            params['random_seed'] += p
            model = cat.train(params = params,
                              pool = dtrain,
                              eval_set = dvalid,
                              iterations = 5000,
                              early_stopping_rounds = 200)
                            #early_stopping_rounds = 1000)
            del dtrain, dvalid, trn_x
            gc.collect()
            preds += ((model.predict((val_x))) / execs)
            test_preds_exec += ((model.predict((test[train_columns]))) / execs)

        test_preds_fold += (test_preds_exec / n_folds)
        oof_preds[val_] = preds
        score_folds.append(np.sqrt(mean_squared_error(val_y, preds)))
        print("FOLD RMSE = {}".format(np.sqrt(mean_squared_error(val_y, preds))))
        del model, val_x
        gc.collect()

    print("############################################################")
    print("{} - MEAN RMSE = {}".format(target, np.mean(score_folds)))
    print("{} - OOF RMSE = {}".format(target, np.sqrt(mean_squared_error(y, oof_preds))))
    print(score_folds)

    if target == 'North':
        north_oof_preds = oof_preds
        north_test_preds = test_preds_fold
    else:
        east_oof_preds = oof_preds
        east_test_preds = test_preds_fold
# Out:
# Fold: 1.0
# Iteration: 1
# 0:	learn: 1.1390152	test: 1.1510069	best: 1.1510069 (0)	total: 170ms	remaining: 14m 11s
# 200:	learn: 0.1753887	test: 0.3046995	best: 0.3046642 (198)	total: 29.6s	remaining: 11m 47s
# 400:	learn: 0.1158543	test: 0.2943623	best: 0.2943069 (396)	total: 59.1s	remaining: 11m 17s
# 600:	learn: 0.0841880	test: 0.2909219	best: 0.2908877 (595)	total: 1m 28s	remaining: 10m 50s
# 800:	learn: 0.0668467	test: 0.2889675	best: 0.2889675 (800)	total: 1m 58s	remaining: 10m 22s
# 1000:	learn: 0.0543826	test: 0.2881949	best: 0.2881815 (996)	total: 2m 29s	remaining: 9m 56s
# 1200:	learn: 0.0461949	test: 0.2875551	best: 0.2875551 (1200)	total: 3m	remaining: 9m 29s
# 1400:	learn: 0.0399352	test: 0.2870239	best: 0.2870239 (1400)	total: 3m 31s	remaining: 9m 2s
# 1600:	learn: 0.0351474	test: 0.2868598	best: 0.2868593 (1574)	total: 4m 2s	remaining: 8m 34s
# 1800:	learn: 0.0310966	test: 0.2867495	best: 0.2867403 (1787)	total: 4m 34s	remaining: 8m 7s
# 2000:	learn: 0.0278833	test: 0.2866444	best: 0.2866394 (1968)	total: 5m 6s	remaining: 7m 39s
# 2200:	learn: 0.0252560	test: 0.2865809	best: 0.2865744 (2186)	total: 5m 38s	remaining: 7m 10s
# 2400:	learn: 0.0228606	test: 0.2865401	best: 0.2865306 (2281)	total: 6m 11s	remaining: 6m 41s
# 2600:	learn: 0.0208351	test: 0.2864967	best: 0.2864967 (2600)	total: 6m 43s	remaining: 6m 12s
# 2800:	learn: 0.0189471	test: 0.2864370	best: 0.2864370 (2800)	total: 7m 16s	remaining: 5m 42s
# 3000:	learn: 0.0173520	test: 0.2863920	best: 0.2863891 (2988)	total: 7m 48s	remaining: 5m 12s
# 3200:	learn: 0.0158716	test: 0.2863942	best: 0.2863740 (3089)	total: 8m 21s	remaining: 4m 41s
# bestTest = 0.2863740268
# bestIteration = 3089
# Shrink model to first 3090 iterations.
# FOLD RMSE = 0.28637407707148205
# Fold: 2.0
# Iteration: 1
# 0:	learn: 1.1267588	test: 1.1929239	best: 1.1929239 (0)	total: 150ms	remaining: 12m 29s
# 200:	learn: 0.1705924	test: 0.3462601	best: 0.3462601 (200)	total: 29.2s	remaining: 11m 38s
# 400:	learn: 0.1128385	test: 0.3316859	best: 0.3316859 (400)	total: 58s	remaining: 11m 5s
# 600:	learn: 0.0811177	test: 0.3264667	best: 0.3264667 (600)	total: 1m 27s	remaining: 10m 41s
# 800:	learn: 0.0638115	test: 0.3240381	best: 0.3240381 (800)	total: 1m 57s	remaining: 10m 15s
# 1000:	learn: 0.0521937	test: 0.3227055	best: 0.3227055 (1000)	total: 2m 27s	remaining: 9m 49s
# 1200:	learn: 0.0439705	test: 0.3220502	best: 0.3220502 (1200)	total: 2m 58s	remaining: 9m 23s
# 1400:	learn: 0.0377222	test: 0.3215572	best: 0.3215572 (1400)	total: 3m 29s	remaining: 8m 57s
# 1600:	learn: 0.0330775	test: 0.3212820	best: 0.3212805 (1597)	total: 4m	remaining: 8m 31s
# 1800:	learn: 0.0295164	test: 0.3211465	best: 0.3211317 (1758)	total: 4m 32s	remaining: 8m 3s
# 2000:	learn: 0.0264288	test: 0.3210428	best: 0.3210428 (2000)	total: 5m 4s	remaining: 7m 35s
# 2200:	learn: 0.0238565	test: 0.3210286	best: 0.3210177 (2023)	total: 5m 36s	remaining: 7m 7s
# bestTest = 0.321017692
# bestIteration = 2023
# Shrink model to first 2024 iterations.
# FOLD RMSE = 0.32101763930546384
# Fold: 3.0
# Iteration: 1
# 0:	learn: 1.1552733	test: 1.0772615	best: 1.0772615 (0)	total: 151ms	remaining: 12m 36s
# 200:	learn: 0.1769560	test: 0.2998071	best: 0.2998071 (200)	total: 29.1s	remaining: 11m 33s
# 400:	learn: 0.1161672	test: 0.2895555	best: 0.2895555 (400)	total: 58.2s	remaining: 11m 8s
# 600:	learn: 0.0854065	test: 0.2859386	best: 0.2859386 (600)	total: 1m 27s	remaining: 10m 42s
# 800:	learn: 0.0668403	test: 0.2836839	best: 0.2836839 (800)	total: 1m 57s	remaining: 10m 15s
# 1000:	learn: 0.0545666	test: 0.2824236	best: 0.2824236 (1000)	total: 2m 28s	remaining: 9m 51s
# 1200:	learn: 0.0461601	test: 0.2816627	best: 0.2816465 (1196)	total: 2m 58s	remaining: 9m 25s
# 1400:	learn: 0.0400492	test: 0.2812465	best: 0.2812438 (1393)	total: 3m 29s	remaining: 8m 58s
# 1600:	learn: 0.0352133	test: 0.2810377	best: 0.2810321 (1598)	total: 4m 1s	remaining: 8m 31s
# 1800:	learn: 0.0314172	test: 0.2808363	best: 0.2808363 (1800)	total: 4m 32s	remaining: 8m 3s
# 2000:	learn: 0.0283727	test: 0.2807179	best: 0.2807167 (1998)	total: 5m 3s	remaining: 7m 35s
# 2200:	learn: 0.0256804	test: 0.2806562	best: 0.2806425 (2123)	total: 5m 35s	remaining: 7m 7s
# 2400:	learn: 0.0233452	test: 0.2806088	best: 0.2805907 (2364)	total: 6m 7s	remaining: 6m 38s
# 2600:	learn: 0.0213462	test: 0.2805457	best: 0.2805439 (2589)	total: 6m 39s	remaining: 6m 8s
# 2800:	learn: 0.0195401	test: 0.2805124	best: 0.2805122 (2799)	total: 7m 11s	remaining: 5m 39s
# 3000:	learn: 0.0179212	test: 0.2804993	best: 0.2804947 (2935)	total: 7m 44s	remaining: 5m 9s
# 3200:	learn: 0.0164275	test: 0.2804677	best: 0.2804648 (3151)	total: 8m 17s	remaining: 4m 39s
# 3400:	learn: 0.0151150	test: 0.2804768	best: 0.2804646 (3250)	total: 8m 49s	remaining: 4m 8s
# bestTest = 0.2804646038
# bestIteration = 3250
# Shrink model to first 3251 iterations.
# FOLD RMSE = 0.2804645879059371
# Fold: 4.0
# Iteration: 1
# bestIteration = 4899
# Shrink model to first 4900 iterations.
# FOLD RMSE = 0.45357375595356875
# Fold: 5.0
# Iteration: 1
# 0:	learn: 1.1392032	test: 1.1472692	best: 1.1472692 (0)	total: 160ms	remaining: 13m 19s
# 200:	learn: 0.1717115	test: 0.3157534	best: 0.3157534 (200)	total: 29.7s	remaining: 11m 49s
# 400:	learn: 0.1157835	test: 0.3026847	best: 0.3026847 (400)	total: 58.6s	remaining: 11m 11s
# 600:	learn: 0.0850315	test: 0.2986830	best: 0.2986830 (600)	total: 1m 28s	remaining: 10m 47s
# 800:	learn: 0.0657349	test: 0.2969572	best: 0.2969572 (800)	total: 1m 58s	remaining: 10m 22s
# 1000:	learn: 0.0538918	test: 0.2962153	best: 0.2962055 (997)	total: 2m 29s	remaining: 9m 56s
# 1200:	learn: 0.0456652	test: 0.2954816	best: 0.2954813 (1198)	total: 3m	remaining: 9m 29s
# 1400:	learn: 0.0395179	test: 0.2951119	best: 0.2951060 (1398)	total: 3m 31s	remaining: 9m 2s
# 1600:	learn: 0.0345219	test: 0.2949010	best: 0.2949010 (1600)	total: 4m 2s	remaining: 8m 35s
# 1800:	learn: 0.0306293	test: 0.2948484	best: 0.2948482 (1799)	total: 4m 34s	remaining: 8m 7s
# 2000:	learn: 0.0273341	test: 0.2947953	best: 0.2947771 (1986)	total: 5m 6s	remaining: 7m 39s
# 2200:	learn: 0.0245989	test: 0.2947352	best: 0.2947352 (2200)	total: 5m 38s	remaining: 7m 11s
# 2400:	learn: 0.0222157	test: 0.2947103	best: 0.2947063 (2254)	total: 6m 11s	remaining: 6m 42s
# 2600:	learn: 0.0202286	test: 0.2946903	best: 0.2946722 (2556)	total: 6m 43s	remaining: 6m 12s
# bestTest = 0.2946721888
# bestIteration = 2556
# Shrink model to first 2557 iterations.
# FOLD RMSE = 0.2946721963850508
# ############################################################
# North - MEAN RMSE = 0.3272204513243005
# North - OOF RMSE = 0.33355121776326946
# [0.28637407707148205, 0.32101763930546384, 0.2804645879059371, 0.45357375595356875, 0.2946721963850508]
# Fold: 1.0
# Iteration: 1
# 0:	learn: 1.1098453	test: 1.1267825	best: 1.1267825 (0)	total: 163ms	remaining: 13m 36s
# 200:	learn: 0.1589213	test: 0.2788926	best: 0.2788573 (199)	total: 30.4s	remaining: 12m 5s
# 400:	learn: 0.1072356	test: 0.2690810	best: 0.2690810 (400)	total: 59.7s	remaining: 11m 24s
# 600:	learn: 0.0811829	test: 0.2652073	best: 0.2652010 (599)	total: 1m 29s	remaining: 10m 55s
# 800:	learn: 0.0639014	test: 0.2630325	best: 0.2630325 (800)	total: 1m 59s	remaining: 10m 28s
# 1000:	learn: 0.0525378	test: 0.2616037	best: 0.2615873 (995)	total: 2m 30s	remaining: 10m 2s
# 1200:	learn: 0.0445130	test: 0.2610533	best: 0.2610533 (1200)	total: 3m 1s	remaining: 9m 34s
# 1400:	learn: 0.0386056	test: 0.2608055	best: 0.2607959 (1390)	total: 3m 33s	remaining: 9m 7s
# 1600:	learn: 0.0339186	test: 0.2605243	best: 0.2605134 (1596)	total: 4m 4s	remaining: 8m 39s
# 1800:	learn: 0.0301184	test: 0.2603835	best: 0.2603833 (1799)	total: 4m 36s	remaining: 8m 11s
# 2000:	learn: 0.0269935	test: 0.2602906	best: 0.2602839 (1924)	total: 5m 8s	remaining: 7m 43s
# 2200:	learn: 0.0242930	test: 0.2603122	best: 0.2602747 (2085)	total: 5m 41s	remaining: 7m 14s
# 2400:	learn: 0.0220677	test: 0.2602501	best: 0.2602501 (2400)	total: 6m 13s	remaining: 6m 44s
# 2600:	learn: 0.0200524	test: 0.2601921	best: 0.2601798 (2554)	total: 6m 46s	remaining: 6m 14s
# 2800:	learn: 0.0182766	test: 0.2601791	best: 0.2601626 (2719)	total: 7m 18s	remaining: 5m 44s
# bestTest = 0.260162564
# bestIteration = 2719
# Shrink model to first 2720 iterations.
# FOLD RMSE = 0.26016264672772726
# Fold: 2.0
# Iteration: 1
# 0:	learn: 1.1077529	test: 1.1291784	best: 1.1291784 (0)	total: 154ms	remaining: 12m 50s
# 200:	learn: 0.1508858	test: 0.3269106	best: 0.3269106 (200)	total: 30s	remaining: 11m 56s
# 400:	learn: 0.1032527	test: 0.3169235	best: 0.3168059 (393)	total: 58.8s	remaining: 11m 13s
# 600:	learn: 0.0778936	test: 0.3125722	best: 0.3125616 (598)	total: 1m 27s	remaining: 10m 43s
# 800:	learn: 0.0605818	test: 0.3106999	best: 0.3106742 (786)	total: 1m 58s	remaining: 10m 19s
# 1000:	learn: 0.0494964	test: 0.3096039	best: 0.3095965 (996)	total: 2m 28s	remaining: 9m 54s
# 1200:	learn: 0.0419841	test: 0.3090214	best: 0.3090099 (1199)	total: 2m 59s	remaining: 9m 28s
# 1400:	learn: 0.0364019	test: 0.3086103	best: 0.3086061 (1399)	total: 3m 30s	remaining: 9m
# 1600:	learn: 0.0322129	test: 0.3083610	best: 0.3083602 (1598)	total: 4m 1s	remaining: 8m 33s
# 1800:	learn: 0.0287711	test: 0.3082403	best: 0.3082403 (1800)	total: 4m 33s	remaining: 8m 5s
# 2000:	learn: 0.0257694	test: 0.3080599	best: 0.3080595 (1999)	total: 5m 5s	remaining: 7m 37s
# 2200:	learn: 0.0231842	test: 0.3079840	best: 0.3079831 (2190)	total: 5m 37s	remaining: 7m 8s
# 2400:	learn: 0.0210828	test: 0.3079210	best: 0.3079193 (2399)	total: 6m 9s	remaining: 6m 39s
# 2600:	learn: 0.0191618	test: 0.3078708	best: 0.3078708 (2600)	total: 6m 41s	remaining: 6m 10s
# 2800:	learn: 0.0175174	test: 0.3078536	best: 0.3078448 (2649)	total: 7m 13s	remaining: 5m 40s
# bestTest = 0.3078447823
# bestIteration = 2649
# Shrink model to first 2650 iterations.
# FOLD RMSE = 0.30784478789381187
# Fold: 3.0
# Iteration: 1
# 0:	learn: 1.0970602	test: 1.1734112	best: 1.1734112 (0)	total: 230ms	remaining: 19m 9s
# 200:	learn: 0.1589469	test: 0.2901641	best: 0.2901641 (200)	total: 29.7s	remaining: 11m 49s
# 400:	learn: 0.1108203	test: 0.2823900	best: 0.2823900 (400)	total: 58.4s	remaining: 11m 9s
# 600:	learn: 0.0833527	test: 0.2783434	best: 0.2783372 (598)	total: 1m 27s	remaining: 10m 42s
# 800:	learn: 0.0655024	test: 0.2761203	best: 0.2761001 (793)	total: 1m 58s	remaining: 10m 19s
# 1000:	learn: 0.0537884	test: 0.2746679	best: 0.2746588 (998)	total: 2m 28s	remaining: 9m 53s
# 1200:	learn: 0.0451798	test: 0.2738576	best: 0.2738576 (1200)	total: 2m 59s	remaining: 9m 28s
# 1400:	learn: 0.0389769	test: 0.2732762	best: 0.2732762 (1400)	total: 3m 31s	remaining: 9m 2s
# 1600:	learn: 0.0342175	test: 0.2728790	best: 0.2728765 (1599)	total: 4m 2s	remaining: 8m 35s
# 1800:	learn: 0.0303518	test: 0.2726247	best: 0.2726247 (1800)	total: 4m 34s	remaining: 8m 8s
# 2000:	learn: 0.0272974	test: 0.2724347	best: 0.2724298 (1998)	total: 5m 6s	remaining: 7m 39s
# 2200:	learn: 0.0247318	test: 0.2723255	best: 0.2723156 (2176)	total: 5m 38s	remaining: 7m 10s
# 2400:	learn: 0.0223762	test: 0.2721806	best: 0.2721802 (2399)	total: 6m 11s	remaining: 6m 41s
# 2600:	learn: 0.0202980	test: 0.2720863	best: 0.2720863 (2600)	total: 6m 43s	remaining: 6m 12s
# 2800:	learn: 0.0184991	test: 0.2720495	best: 0.2720495 (2800)	total: 7m 15s	remaining: 5m 42s
# 3000:	learn: 0.0169316	test: 0.2719923	best: 0.2719919 (2999)	total: 7m 48s	remaining: 5m 12s
# 3200:	learn: 0.0154868	test: 0.2719547	best: 0.2719495 (3192)	total: 8m 21s	remaining: 4m 41s
# 3400:	learn: 0.0142350	test: 0.2719174	best: 0.2719069 (3372)	total: 8m 53s	remaining: 4m 10s
# 3600:	learn: 0.0130835	test: 0.2718798	best: 0.2718777 (3535)	total: 9m 26s	remaining: 3m 40s
# 3800:	learn: 0.0120462	test: 0.2718563	best: 0.2718563 (3799)	total: 9m 59s	remaining: 3m 9s
# 4000:	learn: 0.0111068	test: 0.2718320	best: 0.2718269 (3967)	total: 10m 32s	remaining: 2m 37s
# 4200:	learn: 0.0102450	test: 0.2718150	best: 0.2718145 (4182)	total: 11m 5s	remaining: 2m 6s
# 4400:	learn: 0.0094472	test: 0.2717856	best: 0.2717856 (4400)	total: 11m 39s	remaining: 1m 35s
# 4600:	learn: 0.0087471	test: 0.2717634	best: 0.2717600 (4585)	total: 12m 12s	remaining: 1m 3s
# 4800:	learn: 0.0081015	test: 0.2717481	best: 0.2717476 (4799)	total: 12m 45s	remaining: 31.7s
# 4999:	learn: 0.0075101	test: 0.2717445	best: 0.2717401 (4892)	total: 13m 18s	remaining: 0us
# bestTest = 0.2717401167
# bestIteration = 4892
# Shrink model to first 4893 iterations.
# FOLD RMSE = 0.2717401434607967
# Fold: 4.0
# Iteration: 1
# 0:	learn: 1.1379345	test: 1.0026344	best: 1.0026344 (0)	total: 213ms	remaining: 17m 42s
# 200:	learn: 0.1552169	test: 0.3143637	best: 0.3143637 (200)	total: 30.3s	remaining: 12m 3s
# 400:	learn: 0.1057725	test: 0.3069193	best: 0.3069002 (396)	total: 59.9s	remaining: 11m 27s
# 600:	learn: 0.0802275	test: 0.3042748	best: 0.3042748 (600)	total: 1m 29s	remaining: 10m 57s
# 800:	learn: 0.0628206	test: 0.3029431	best: 0.3029369 (799)	total: 2m	remaining: 10m 32s
# 1000:	learn: 0.0517994	test: 0.3020237	best: 0.3020234 (993)	total: 2m 31s	remaining: 10m 5s
# 1200:	learn: 0.0439044	test: 0.3016144	best: 0.3015975 (1167)	total: 3m 2s	remaining: 9m 38s
# 1400:	learn: 0.0381531	test: 0.3013805	best: 0.3013636 (1362)	total: 3m 34s	remaining: 9m 10s
# 1600:	learn: 0.0336101	test: 0.3011517	best: 0.3011410 (1594)	total: 4m 6s	remaining: 8m 42s
# 1800:	learn: 0.0300102	test: 0.3010531	best: 0.3010482 (1776)	total: 4m 38s	remaining: 8m 14s
# 2000:	learn: 0.0269217	test: 0.3009854	best: 0.3009854 (2000)	total: 5m 10s	remaining: 7m 45s
# 2200:	learn: 0.0243047	test: 0.3008798	best: 0.3008798 (2200)	total: 5m 43s	remaining: 7m 16s
# 2400:	learn: 0.0220844	test: 0.3008628	best: 0.3008530 (2368)	total: 6m 15s	remaining: 6m 46s
# 2600:	learn: 0.0202234	test: 0.3008186	best: 0.3008169 (2594)	total: 6m 47s	remaining: 6m 16s
# 2800:	learn: 0.0185100	test: 0.3007820	best: 0.3007820 (2800)	total: 7m 20s	remaining: 5m 45s
# 3000:	learn: 0.0169707	test: 0.3008026	best: 0.3007744 (2817)	total: 7m 53s	remaining: 5m 15s
# bestTest = 0.3007744353
# bestIteration = 2817
# Shrink model to first 2818 iterations.
# FOLD RMSE = 0.3007744368288265
# Fold: 5.0
# Iteration: 1
# 0:	learn: 1.1085577	test: 1.1266808	best: 1.1266808 (0)	total: 158ms	remaining: 13m 9s
# 200:	learn: 0.1603510	test: 0.3090465	best: 0.3090465 (200)	total: 30.1s	remaining: 11m 58s
# 400:	learn: 0.1081903	test: 0.2989068	best: 0.2989068 (400)	total: 59.7s	remaining: 11m 24s
# 600:	learn: 0.0813306	test: 0.2958125	best: 0.2958125 (600)	total: 1m 29s	remaining: 10m 54s
# 800:	learn: 0.0637274	test: 0.2948895	best: 0.2948895 (800)	total: 1m 59s	remaining: 10m 28s
# 1000:	learn: 0.0521276	test: 0.2942003	best: 0.2941839 (999)	total: 2m 30s	remaining: 10m 1s
# 1200:	learn: 0.0439993	test: 0.2937359	best: 0.2937345 (1181)	total: 3m 1s	remaining: 9m 34s
# 1400:	learn: 0.0382876	test: 0.2935103	best: 0.2934912 (1392)	total: 3m 32s	remaining: 9m 7s
# 1600:	learn: 0.0338791	test: 0.2933696	best: 0.2933357 (1571)	total: 4m 4s	remaining: 8m 38s
# 1800:	learn: 0.0301728	test: 0.2932116	best: 0.2931913 (1736)	total: 4m 36s	remaining: 8m 10s
# 2000:	learn: 0.0271376	test: 0.2931428	best: 0.2931428 (2000)	total: 5m 7s	remaining: 7m 41s
# 2200:	learn: 0.0244843	test: 0.2930855	best: 0.2930710 (2149)	total: 5m 40s	remaining: 7m 12s
# 2400:	learn: 0.0222007	test: 0.2930148	best: 0.2930145 (2397)	total: 6m 12s	remaining: 6m 43s
# 2600:	learn: 0.0201740	test: 0.2929861	best: 0.2929746 (2558)	total: 6m 44s	remaining: 6m 13s
# 2800:	learn: 0.0184504	test: 0.2929738	best: 0.2929649 (2690)	total: 7m 16s	remaining: 5m 42s
# 3000:	learn: 0.0168847	test: 0.2929358	best: 0.2929334 (2996)	total: 7m 49s	remaining: 5m 12s
# bestTest = 0.2929333891
# bestIteration = 2996
# Shrink model to first 2997 iterations.
# FOLD RMSE = 0.2929334327542034
# ############################################################
# East - MEAN RMSE = 0.28669108953307315
# East - OOF RMSE = 0.28725256025979573
# [0.26016264672772726, 0.30784478789381187, 0.2717401434607967, 0.3007744368288265, 0.2929334327542034]
# CPU times: user 1h 59min 8s, sys: 36min 7s, total: 2h 35min 15s
# Wall time: 1h 32min 59s

# %%
all_preds = np.concatenate([north_oof_preds, east_oof_preds])
all_target = np.concatenate([train.North, train.East])

# %%
print("ALL - OOF RMSE = {}".format(np.sqrt(mean_squared_error(all_target, all_preds))))
# Out:
# ALL - OOF RMSE = 0.3112639139437525

# %%
sub_oof = pd.DataFrame({
    'Filename': train.Filename,
    'oof_north': north_oof_preds,
    'oof_east': east_oof_preds
})

sub_oof.to_csv('oof_cat_seq_003.csv', index=False)

# %%
sub_north_test = pd.DataFrame({
    'Id': test.Filename,
    'Predicted': north_test_preds
})

sub_east_test = pd.DataFrame({
    'Id': test.Filename,
    'Predicted': east_test_preds
})

# %%
sub_north_test.Id = sub_north_test['Id'].astype(str) + ':North'
sub_east_test.Id  = sub_east_test['Id'].astype(str) + ':East'

sub_all_test = pd.concat([sub_north_test, sub_east_test])

# %%
sub_all_test[['Id', 'Predicted']].to_csv('sub_cat_seq_003.csv', index=False)

# %%
sub_all_test
# Out:
#                                                Id  Predicted
# 0      0f57a863af3b7e5bf59a94319a408ff7.jpg:North  -0.420965
# 1      b7d4e3a6acb3b956d8b09416958e8892.jpg:North  -0.475053
# 2      9a1bd630a47dabafa6f4cab7338d01df.jpg:North  -0.500408
# 3      3f6ebf8aef0f352720bc0cb534d878b6.jpg:North  -0.530086
# 4      7e810f05bd88ff0f86dce7116b9fa527.jpg:North  -0.516265
# ...                                           ...        ...
# 55026   fc65c23ae61ce2c6fdbc637a8296d1d7.jpg:East   0.713813
# 55027   fc6c0d99ec42bad5e2d5fbb1e71c5a50.jpg:East   1.131162
# 55028   fdbb732633c6a3d32a67fc56edc7cde4.jpg:East  -0.105026
# 55029   feac1b902c7487dcbdf298bd4be75690.jpg:East  -0.500688
# 55030   ff76ffce183c11f84489bbd0a34a2fcf.jpg:East  -1.183757
#
# [110062 rows x 2 columns]
