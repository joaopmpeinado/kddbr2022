# %%
import os
import pandas as pd
import numpy as np
import xgboost as xgb
from lightgbm.callback import early_stopping
from sklearn.model_selection import KFold, GroupKFold
from tqdm import tqdm
from sklearn.metrics import mean_squared_error
import warnings

import math
# Out:
# <style type='text/css'>
# .datatable table.frame { margin-bottom: 0; }
# .datatable table.frame thead { border-bottom: none; }
# .datatable table.frame tr.coltypes td {  color: #FFFFFF;  line-height: 6px;  padding: 0 0.5em;}
# .datatable .bool    { background: #DDDD99; }
# .datatable .object  { background: #565656; }
# .datatable .int     { background: #5D9E5D; }
# .datatable .float   { background: #4040CC; }
# .datatable .str     { background: #CC4040; }
# .datatable .time    { background: #40CC40; }
# .datatable .row_index {  background: var(--jp-border-color3);  border-right: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  font-size: 9px;}
# .datatable .frame tbody td { text-align: left; }
# .datatable .frame tr.coltypes .row_index {  background: var(--jp-border-color0);}
# .datatable th:nth-child(2) { padding-left: 12px; }
# .datatable .hellipsis {  color: var(--jp-cell-editor-border-color);}
# .datatable .vellipsis {  background: var(--jp-layout-color0);  color: var(--jp-cell-editor-border-color);}
# .datatable .na {  color: var(--jp-cell-editor-border-color);  font-size: 80%;}
# .datatable .sp {  opacity: 0.25;}
# .datatable .footer { font-size: 9px; }
# .datatable .frame_dimensions {  background: var(--jp-border-color3);  border-top: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  display: inline-block;  opacity: 0.6;  padding: 1px 10px 1px 5px;}
# </style>

# %%
pd.set_option('display.width', 1000)
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
warnings.filterwarnings('ignore')

path = os.getcwd()

# %%
train = pd.read_csv('../input/kddbr2022apk/train_sequence_fold.csv')
test = pd.read_csv('../input/kddbr2022apk/test_sequence.csv')
df = pd.concat([train, test])

features_1 = pd.read_csv('../input/kddbr2022apk/complete_04.csv')
features_1 = features_1[["Filename","w_std","w_mean","w_median","w_min","w_max","w_var","n_std","n_mean","n_median","n_min","n_max","n_var","d_std","d_mean","d_median","d_min","d_max","d_var"]]
features_1.columns = ["Filename","_w_std","_w_mean","_w_median","_w_min","_w_max","_w_var","_n_std","_n_mean","_n_median","_n_min","_n_max","_n_var","_d_std","_d_mean","_d_median","_d_min","_d_max","_d_var"]
features_2 = pd.read_csv('../input/kddbr2022apk/complete_05.csv')
features_3 = pd.read_csv('../input/kddbr2022apk/complete_06.csv')

features = pd.merge(features_1, features_2, on='Filename', how='left')
features = pd.merge(features, features_3, on='Filename', how='left')

mario_features_tr = pd.read_csv('../input/kddbr2022apk/mario_train_vec_v1.csv')
mario_features_ts = pd.read_csv('../input/kddbr2022apk/mario_test_vec_v1.csv')

mario_features = pd.concat([mario_features_tr, mario_features_ts])
mario_features2 = pd.read_csv('../input/kddbr2022apk/vecs_v3_fe.csv')

# %%
df = pd.merge(df, features, on='Filename', how='left')
df = pd.merge(df, mario_features, on='Filename', how='left')
df = pd.merge(df, mario_features2, on='Filename', how='left')

df = df.sort_values(by=['run_id', 'run_seq_id']).reset_index(drop=True)

# %%
df['sqrt_altitude'] = np.sqrt(df['Altitude'])
df['sqrt_delta'] = np.sqrt(df['Delta'])
df['sqrt_altitude_delta'] = np.sqrt(df['Altitude'] + df['Delta'])

df['pow2_altitude'] = (df['Altitude'] ** 2)
df['pow2_delta'] = (df['Delta'] ** 2)
df['pow2_altitude_delta'] = (df['Altitude'] + df['Delta']) ** 2

tgt_columns = [
    'Delta', 'Altitude', 
    'base_05_n_mean', '_n_mean', 'base_05_f05_H_1', 'base_05_n_median', 'base_05_n_max', 'base_05_n_min', 'base_05_f05_H_4', 'x', 'base_05_f05_H_25', 'base_05_f05_H_7', 'x_mean', 'x1_mean', 'x2_mean',
    'base_05_w_mean', '_w_mean', 'base_05_f05_W_21', 'base_05_w_median', 'base_05_w_max', 'base_05_w_min', 'base_05_f05_W_18', 'y', 'base_05_f05_W_6', 'base_05_f05_W_0', 'y_mean', 'y1_mean', 'y2_mean',
#     'base_06_n_mean', 'base_06_f06_H_1', 'base_06_n_median', 'base_06_n_max',
#     'base_06_w_mean', 'base_06_f06_W_21', 'base_06_w_median', 'base_06_w_max'
]

for col in tqdm(tgt_columns):
    df['shift_'+col] = df.groupby('run_id')[col].shift().reset_index(0,drop=True)
    df['next_'+col] = df.groupby('run_id')[col].shift(-1).reset_index(0,drop=True)
    df['shift2_'+col] = df.groupby('run_id')[col].shift(2).reset_index(0,drop=True)
    df['next2_'+col] = df.groupby('run_id')[col].shift(-2).reset_index(0,drop=True)
    df['shift3_'+col] = df.groupby('run_id')[col].shift(3).reset_index(0,drop=True)
    df['next3_'+col] = df.groupby('run_id')[col].shift(-3).reset_index(0,drop=True)
    df['shift4_'+col] = df.groupby('run_id')[col].shift(4).reset_index(0,drop=True)
    df['next4_'+col] = df.groupby('run_id')[col].shift(-4).reset_index(0,drop=True)
    df['shift5_'+col] = df.groupby('run_id')[col].shift(5).reset_index(0,drop=True)
    df['next5_'+col] = df.groupby('run_id')[col].shift(-5).reset_index(0,drop=True)
    df['seq_avg_w3_'+col] = df.groupby('run_id')[col].rolling(3).mean().reset_index(0,drop=True)
    df['seq_avg_w2_'+col] = df.groupby('run_id')[col].rolling(2).mean().reset_index(0,drop=True)
    df['seq_avg_w5_'+col] = df.groupby('run_id')[col].rolling(5).mean().reset_index(0,drop=True)
    df['seq_avg_w10_'+col] = df.groupby('run_id')[col].rolling(10).mean().reset_index(0,drop=True)
    df['seq_avg_w25_'+col] = df.groupby('run_id')[col].rolling(25).mean().reset_index(0,drop=True)
    df['seq_avg_w50_'+col] = df.groupby('run_id')[col].rolling(50).mean().reset_index(0,drop=True)
    df['seq_std_w3_'+col] = df.groupby('run_id')[col].rolling(3).std().reset_index(0,drop=True)
    df['seq_std_w2_'+col] = df.groupby('run_id')[col].rolling(2).std().reset_index(0,drop=True)
    df['seq_std_w5_'+col] = df.groupby('run_id')[col].rolling(5).std().reset_index(0,drop=True)
    df['seq_std_w10_'+col] = df.groupby('run_id')[col].rolling(10).std().reset_index(0,drop=True)
    df['seq_std_w25_'+col] = df.groupby('run_id')[col].rolling(25).std().reset_index(0,drop=True)
    df['seq_std_w50_'+col] = df.groupby('run_id')[col].rolling(50).std().reset_index(0,drop=True)
    df['seq_max_w3_'+col] = df.groupby('run_id')[col].rolling(3).max().reset_index(0,drop=True)
    df['seq_max_w2_'+col] = df.groupby('run_id')[col].rolling(2).max().reset_index(0,drop=True)
    df['seq_max_w5_'+col] = df.groupby('run_id')[col].rolling(5).max().reset_index(0,drop=True)
    df['seq_max_w10_'+col] = df.groupby('run_id')[col].rolling(10).max().reset_index(0,drop=True)
    df['seq_max_w25_'+col] = df.groupby('run_id')[col].rolling(25).max().reset_index(0,drop=True)
    df['seq_max_w50_'+col] = df.groupby('run_id')[col].rolling(50).max().reset_index(0,drop=True)
    df['seq_min_w3_'+col] = df.groupby('run_id')[col].rolling(3).min().reset_index(0,drop=True)
    df['seq_min_w2_'+col] = df.groupby('run_id')[col].rolling(2).min().reset_index(0,drop=True)
    df['seq_min_w5_'+col] = df.groupby('run_id')[col].rolling(5).min().reset_index(0,drop=True)
    df['seq_min_w10_'+col] = df.groupby('run_id')[col].rolling(10).min().reset_index(0,drop=True)
    df['seq_min_w25_'+col] = df.groupby('run_id')[col].rolling(25).min().reset_index(0,drop=True)
    df['seq_min_w50_'+col] = df.groupby('run_id')[col].rolling(50).min().reset_index(0,drop=True)
    df['seq_diff_last_'+col] = df.groupby('run_id')[col].diff(1).reset_index(0,drop=True)
    df['seq_diff_next_'+col] = df.groupby('run_id')[col].diff(-1).reset_index(0,drop=True)
    df['seq_diff_last2_'+col] = df.groupby('run_id')[col].diff(2).reset_index(0,drop=True)
    df['seq_diff_next2_'+col] = df.groupby('run_id')[col].diff(-2).reset_index(0,drop=True)
    df['seq_diff_last3_'+col] = df.groupby('run_id')[col].diff(3).reset_index(0,drop=True)
    df['seq_diff_next3_'+col] = df.groupby('run_id')[col].diff(-3).reset_index(0,drop=True)
    df['seq_diff_last4_'+col] = df.groupby('run_id')[col].diff(4).reset_index(0,drop=True)
    df['seq_diff_next4_'+col] = df.groupby('run_id')[col].diff(-4).reset_index(0,drop=True)
    df['seq_diff_last5_'+col] = df.groupby('run_id')[col].diff(5).reset_index(0,drop=True)
    df['seq_diff_next5_'+col] = df.groupby('run_id')[col].diff(-5).reset_index(0,drop=True)
    df['seq_div_last_'+col] = df[col] / df['shift_'+col]
    df['seq_div_next_'+col] = df[col] / df['next_'+col]
    df['seq_div_last2_'+col] = df[col] / df['shift2_'+col]
    df['seq_div_next2_'+col] = df[col] / df['next2_'+col]
    df['seq_div_last3_'+col] = df[col] / df['shift3_'+col]
    df['seq_div_next3_'+col] = df[col] / df['next3_'+col]

#     df[col+'_inverse'] = df.groupby('run_id')[col].transform(lambda x: x[::-1])
#     df['seq_avg_next_w3_'+col] = df.groupby('run_id')[col+'_inverse'].rolling(3).mean().reset_index(0,drop=True)
#     df['seq_avg_next_w5_'+col] = df.groupby('run_id')[col+'_inverse'].rolling(5).mean().reset_index(0,drop=True)
#     df['seq_std_next_w3_'+col] = df.groupby('run_id')[col+'_inverse'].rolling(3).std().reset_index(0,drop=True)    
#     df['seq_std_next_w5_'+col] = df.groupby('run_id')[col+'_inverse'].rolling(5).std().reset_index(0,drop=True)
#     df['seq_max_next_w3_'+col] = df.groupby('run_id')[col+'_inverse'].rolling(3).max().reset_index(0,drop=True)
#     df['seq_max_next_w5_'+col] = df.groupby('run_id')[col+'_inverse'].rolling(5).max().reset_index(0,drop=True) 
#     df['seq_min_next_w3_'+col] = df.groupby('run_id')[col+'_inverse'].rolling(3).min().reset_index(0,drop=True)
#     df['seq_min_next_w5_'+col] = df.groupby('run_id')[col+'_inverse'].rolling(5).min().reset_index(0,drop=True)
#     del df[col+'_inverse']
    

df['r_vetorial_now'] = (df['base_05_n_mean'] ** 2) + (df['base_05_w_mean'] ** 2)
df['shift_r_vetorial'] = (df['shift_base_05_n_mean'] ** 2) + (df['shift_base_05_w_mean'] ** 2)
df['shift2_r_vetorial'] = (df['shift2_base_05_n_mean'] ** 2) + (df['shift2_base_05_w_mean'] ** 2)
df['next_r_vetorial'] = (df['next_base_05_n_mean'] ** 2) + (df['next_base_05_w_mean'] ** 2)
df['next2_r_vetorial'] = (df['next2_base_05_n_mean'] ** 2) + (df['next2_base_05_w_mean'] ** 2)
df['avg_shift_r_vet'] = (df['r_vetorial_now'] + df['shift_r_vetorial'] + df['shift2_r_vetorial']) / 3
df['avg_next_r_vet'] = (df['r_vetorial_now'] + df['next_r_vetorial'] + df['next2_r_vetorial']) / 3
df['avg_all_r_vet'] = (df['r_vetorial_now'] + df['next_r_vetorial'] + df['next2_r_vetorial'] + df['shift_r_vetorial'] + df['shift2_r_vetorial']) / 5

df['div_r_next2_next'] = df['next2_r_vetorial'] / df['next_r_vetorial']
df['div_r_next_now'] = df['next_r_vetorial'] / df['r_vetorial_now']
df['div_r_now_shift'] = df['r_vetorial_now'] / df['shift_r_vetorial']
df['div_r_shift1_shift2'] = df['shift_r_vetorial'] / df['shift2_r_vetorial']
df['avg_div_r'] = (df['div_r_next2_next'] + df['div_r_next_now'] + df['div_r_now_shift'] + df['div_r_shift1_shift2']) / 4
# Out:
# 100%|██████████| 28/28 [02:32<00:00,  5.45s/it]

# %%
print(df.shape)
# Out:
# (146262, 1587)

# %%
train = df.loc[~df.North.isnull(), :].sort_values(by=['run_id', 'run_seq_id']).reset_index(drop=True)
test = df.loc[df.North.isnull(), :].sort_values(by=['run_id', 'run_seq_id']).reset_index(drop=True)

# %%
import gc
del df
gc.collect()
# Out:
# 23

# %%
train_columns = [col for col in train.columns if col not in ['Filename', 'North', 'East', 'fold', 'run_id', 'run_seq_id']]

# %%
n_folds = 5

north_oof_preds = np.zeros(len(train))
east_oof_preds = np.zeros(len(train))

north_test_preds = np.zeros(len(test))
east_test_preds = np.zeros(len(test))

targets = ['North', 'East']

# %%
train = train.replace([np.inf, -np.inf], np.nan)
#trn_x = trn_x.fillna(-999)
test = test.replace([np.inf, -np.inf], np.nan)

# %%
# %%time
for target in targets:
    y = train[target]
    oof_preds = np.zeros(len(train))
    test_preds_fold = np.zeros(len(test))
    score_folds  = []

    # folds = GroupKFold(n_splits=n_folds)
    # for fold_, (trn_, val_) in enumerate(folds.split(y, y, train.run_id)):
    for fold_ in train.fold.sort_values().unique():
        print("Fold: {}".format(fold_))

        trn_ = train.loc[train.fold != fold_].index
        val_ = train.loc[train.fold == fold_].index

        trn_x, trn_y = train.loc[trn_, train_columns], y.loc[trn_]
        val_x, val_y = train.loc[val_, train_columns], y.loc[val_]
        
        dtrain = xgb.DMatrix(trn_x, trn_y)
        dvalid = xgb.DMatrix(val_x, val_y)
        
        watchlist = [(dtrain, 'train'), (dvalid, 'valid')]
        
        params = {
          'objective': "reg:squarederror", #"reg:logistic",
          'booster': "gbtree",
          'eval_metric': 'rmse', 
          'colsample_bytree': 0.85,
          'subsample': 0.85,
          'eta': 0.1,
          'max_depth': 5,
          'min_child_weight': 64, 
          'max_bin': 32,
          'nthread':-1,
          'seed': 99,
          'tree_method': 'gpu_hist'
        }
        
        execs = 1
        preds = np.zeros(len(val_x))
        test_preds_exec = np.zeros(len(test))
        
        for p in range(0,execs):
            print("Iteration: {}".format(p+1))
            params['seed'] += p
            model = xgb.train(params, dtrain, 
                               10000, watchlist, 
                               maximize=False, 
                               early_stopping_rounds = 200, 
                               verbose_eval=200)
                            #early_stopping_rounds = 1000)
            
            preds += ((model.predict(xgb.DMatrix(val_x))) / execs)
            test_preds_exec += ((model.predict(xgb.DMatrix(test[train_columns]))) / execs)

        test_preds_fold += (test_preds_exec / n_folds)
        oof_preds[val_] = preds
        score_folds.append(np.sqrt(mean_squared_error(val_y, preds)))
        print("FOLD RMSE = {}".format(np.sqrt(mean_squared_error(val_y, preds))))
        del dtrain, dvalid, trn_x, val_x
        gc.collect()

    print("############################################################")
    print("{} - MEAN RMSE = {}".format(target, np.mean(score_folds)))
    print("{} - OOF RMSE = {}".format(target, np.sqrt(mean_squared_error(y, oof_preds))))
    print(score_folds)

    if target == 'North':
        north_oof_preds = oof_preds
        north_test_preds = test_preds_fold
    else:
        east_oof_preds = oof_preds
        east_test_preds = test_preds_fold
# Out:
# Fold: 1.0
# Iteration: 1
# [0]	train-rmse:1.18071	valid-rmse:1.17386
# [100]	train-rmse:0.24669	valid-rmse:0.30095
# [200]	train-rmse:0.20467	valid-rmse:0.29046
# [300]	train-rmse:0.18052	valid-rmse:0.28468
# [400]	train-rmse:0.16379	valid-rmse:0.28180
# [500]	train-rmse:0.15105	valid-rmse:0.28014
# [600]	train-rmse:0.13989	valid-rmse:0.27923
# [700]	train-rmse:0.12975	valid-rmse:0.27806
# [800]	train-rmse:0.12158	valid-rmse:0.27679
# [900]	train-rmse:0.11460	valid-rmse:0.27647
# [1000]	train-rmse:0.10788	valid-rmse:0.27597
# [1100]	train-rmse:0.10208	valid-rmse:0.27534
# [1200]	train-rmse:0.09706	valid-rmse:0.27518
# [1300]	train-rmse:0.09240	valid-rmse:0.27513
# [1400]	train-rmse:0.08788	valid-rmse:0.27498
# [1500]	train-rmse:0.08391	valid-rmse:0.27489
# [1600]	train-rmse:0.08007	valid-rmse:0.27475
# [1700]	train-rmse:0.07669	valid-rmse:0.27476
# [1800]	train-rmse:0.07343	valid-rmse:0.27469
# [1900]	train-rmse:0.07033	valid-rmse:0.27448
# [2000]	train-rmse:0.06715	valid-rmse:0.27433
# [2100]	train-rmse:0.06434	valid-rmse:0.27411
# [2200]	train-rmse:0.06155	valid-rmse:0.27394
# [2300]	train-rmse:0.05892	valid-rmse:0.27392
# [2400]	train-rmse:0.05643	valid-rmse:0.27365
# [2500]	train-rmse:0.05388	valid-rmse:0.27342
# [2600]	train-rmse:0.05175	valid-rmse:0.27339
# [2700]	train-rmse:0.04971	valid-rmse:0.27343
# [2800]	train-rmse:0.04791	valid-rmse:0.27330
# [2900]	train-rmse:0.04604	valid-rmse:0.27324
# [3000]	train-rmse:0.04431	valid-rmse:0.27318
# [3100]	train-rmse:0.04260	valid-rmse:0.27308
# [3200]	train-rmse:0.04109	valid-rmse:0.27296
# [3300]	train-rmse:0.03959	valid-rmse:0.27290
# [3400]	train-rmse:0.03819	valid-rmse:0.27280
# [3500]	train-rmse:0.03688	valid-rmse:0.27268
# [3600]	train-rmse:0.03555	valid-rmse:0.27260
# [3700]	train-rmse:0.03426	valid-rmse:0.27263
# [3800]	train-rmse:0.03303	valid-rmse:0.27265
# [3818]	train-rmse:0.03282	valid-rmse:0.27262
# FOLD RMSE = 0.2726208048836069
# Fold: 2.0
# Iteration: 1
# [0]	train-rmse:1.16613	valid-rmse:1.23254
# [100]	train-rmse:0.23816	valid-rmse:0.32882
# [200]	train-rmse:0.19581	valid-rmse:0.31975
# [300]	train-rmse:0.16975	valid-rmse:0.31572
# [400]	train-rmse:0.14966	valid-rmse:0.31302
# [500]	train-rmse:0.13465	valid-rmse:0.31084
# [600]	train-rmse:0.12246	valid-rmse:0.30895
# [700]	train-rmse:0.11287	valid-rmse:0.30838
# [800]	train-rmse:0.10430	valid-rmse:0.30701
# [900]	train-rmse:0.09696	valid-rmse:0.30679
# [1000]	train-rmse:0.09075	valid-rmse:0.30592
# [1100]	train-rmse:0.08470	valid-rmse:0.30531
# [1200]	train-rmse:0.07947	valid-rmse:0.30488
# [1300]	train-rmse:0.07455	valid-rmse:0.30441
# [1400]	train-rmse:0.06968	valid-rmse:0.30449
# [1500]	train-rmse:0.06549	valid-rmse:0.30430
# [1600]	train-rmse:0.06203	valid-rmse:0.30375
# [1700]	train-rmse:0.05873	valid-rmse:0.30350
# [1800]	train-rmse:0.05569	valid-rmse:0.30337
# [1900]	train-rmse:0.05298	valid-rmse:0.30309
# [2000]	train-rmse:0.05044	valid-rmse:0.30287
# [2100]	train-rmse:0.04796	valid-rmse:0.30279
# [2200]	train-rmse:0.04582	valid-rmse:0.30265
# [2300]	train-rmse:0.04382	valid-rmse:0.30266
# [2364]	train-rmse:0.04263	valid-rmse:0.30264
# FOLD RMSE = 0.30264783770529124
# Fold: 3.0
# Iteration: 1
# [0]	train-rmse:1.18961	valid-rmse:1.13458
# [100]	train-rmse:0.25124	valid-rmse:0.26936
# [200]	train-rmse:0.21546	valid-rmse:0.26455
# [300]	train-rmse:0.19090	valid-rmse:0.26195
# [400]	train-rmse:0.17060	valid-rmse:0.26071
# [500]	train-rmse:0.15707	valid-rmse:0.25878
# [600]	train-rmse:0.14601	valid-rmse:0.25800
# [700]	train-rmse:0.13586	valid-rmse:0.25754
# [800]	train-rmse:0.12710	valid-rmse:0.25670
# [900]	train-rmse:0.11970	valid-rmse:0.25631
# [1000]	train-rmse:0.11316	valid-rmse:0.25619
# [1100]	train-rmse:0.10708	valid-rmse:0.25640
# [1200]	train-rmse:0.10181	valid-rmse:0.25620
# [1213]	train-rmse:0.10101	valid-rmse:0.25636
# FOLD RMSE = 0.256377136150429
# Fold: 4.0
# Iteration: 1
# [0]	train-rmse:1.17800	valid-rmse:1.17838
# [100]	train-rmse:0.19513	valid-rmse:0.46991
# [200]	train-rmse:0.15239	valid-rmse:0.46424
# [300]	train-rmse:0.12795	valid-rmse:0.46221
# [400]	train-rmse:0.11083	valid-rmse:0.46144
# [500]	train-rmse:0.09812	valid-rmse:0.46104
# [600]	train-rmse:0.08692	valid-rmse:0.45949
# [700]	train-rmse:0.07888	valid-rmse:0.45960
# [800]	train-rmse:0.07196	valid-rmse:0.45949
# [900]	train-rmse:0.06609	valid-rmse:0.45923
# [1000]	train-rmse:0.06144	valid-rmse:0.45912
# [1100]	train-rmse:0.05722	valid-rmse:0.45899
# [1200]	train-rmse:0.05358	valid-rmse:0.45877
# [1300]	train-rmse:0.05035	valid-rmse:0.45860
# [1400]	train-rmse:0.04763	valid-rmse:0.45850
# [1500]	train-rmse:0.04500	valid-rmse:0.45834
# [1600]	train-rmse:0.04277	valid-rmse:0.45828
# [1700]	train-rmse:0.04075	valid-rmse:0.45806
# [1800]	train-rmse:0.03885	valid-rmse:0.45806
# [1900]	train-rmse:0.03716	valid-rmse:0.45798
# [2000]	train-rmse:0.03559	valid-rmse:0.45788
# [2100]	train-rmse:0.03406	valid-rmse:0.45785
# [2200]	train-rmse:0.03268	valid-rmse:0.45783
# [2300]	train-rmse:0.03141	valid-rmse:0.45782
# [2400]	train-rmse:0.03020	valid-rmse:0.45769
# [2500]	train-rmse:0.02909	valid-rmse:0.45760
# [2600]	train-rmse:0.02800	valid-rmse:0.45761
# [2700]	train-rmse:0.02701	valid-rmse:0.45753
# [2800]	train-rmse:0.02609	valid-rmse:0.45749
# [2900]	train-rmse:0.02520	valid-rmse:0.45746
# [3000]	train-rmse:0.02436	valid-rmse:0.45747
# [3100]	train-rmse:0.02354	valid-rmse:0.45746
# [3200]	train-rmse:0.02282	valid-rmse:0.45747
# [3252]	train-rmse:0.02244	valid-rmse:0.45748
# FOLD RMSE = 0.4574781075933333
# Fold: 5.0
# Iteration: 1
# [0]	train-rmse:1.17906	valid-rmse:1.17836
# [100]	train-rmse:0.24020	valid-rmse:0.33042
# [200]	train-rmse:0.19619	valid-rmse:0.32015
# [300]	train-rmse:0.16973	valid-rmse:0.31380
# [400]	train-rmse:0.14981	valid-rmse:0.31137
# [500]	train-rmse:0.13471	valid-rmse:0.30847
# [600]	train-rmse:0.12318	valid-rmse:0.30748
# [700]	train-rmse:0.11279	valid-rmse:0.30567
# [800]	train-rmse:0.10424	valid-rmse:0.30421
# [900]	train-rmse:0.09674	valid-rmse:0.30342
# [1000]	train-rmse:0.08976	valid-rmse:0.30255
# [1100]	train-rmse:0.08374	valid-rmse:0.30212
# [1200]	train-rmse:0.07830	valid-rmse:0.30181
# [1300]	train-rmse:0.07351	valid-rmse:0.30136
# [1400]	train-rmse:0.06936	valid-rmse:0.30096
# [1500]	train-rmse:0.06548	valid-rmse:0.30052
# [1600]	train-rmse:0.06189	valid-rmse:0.30010
# [1700]	train-rmse:0.05850	valid-rmse:0.30005
# [1800]	train-rmse:0.05555	valid-rmse:0.29983
# [1900]	train-rmse:0.05293	valid-rmse:0.29982
# [2000]	train-rmse:0.05027	valid-rmse:0.29971
# [2100]	train-rmse:0.04792	valid-rmse:0.29939
# [2200]	train-rmse:0.04563	valid-rmse:0.29943
# [2300]	train-rmse:0.04366	valid-rmse:0.29937
# [2400]	train-rmse:0.04171	valid-rmse:0.29918
# [2500]	train-rmse:0.03990	valid-rmse:0.29911
# [2600]	train-rmse:0.03816	valid-rmse:0.29906
# [2700]	train-rmse:0.03658	valid-rmse:0.29912
# [2800]	train-rmse:0.03512	valid-rmse:0.29911
# [2863]	train-rmse:0.03423	valid-rmse:0.29912
# FOLD RMSE = 0.2991287747248766
# ############################################################
# North - MEAN RMSE = 0.3176505322115074
# North - OOF RMSE = 0.32570218145244395
# [0.2726208048836069, 0.30264783770529124, 0.256377136150429, 0.4574781075933333, 0.2991287747248766]
# Fold: 1.0
# Iteration: 1
# [0]	train-rmse:1.14805	valid-rmse:1.17476
# [100]	train-rmse:0.20115	valid-rmse:0.28065
# [200]	train-rmse:0.15849	valid-rmse:0.27050
# [300]	train-rmse:0.13482	valid-rmse:0.26531
# [400]	train-rmse:0.11768	valid-rmse:0.26245
# [500]	train-rmse:0.10582	valid-rmse:0.26118
# [600]	train-rmse:0.09616	valid-rmse:0.25982
# [700]	train-rmse:0.08786	valid-rmse:0.25915
# [800]	train-rmse:0.08074	valid-rmse:0.25850
# [900]	train-rmse:0.07446	valid-rmse:0.25788
# [1000]	train-rmse:0.06943	valid-rmse:0.25748
# [1100]	train-rmse:0.06474	valid-rmse:0.25702
# [1200]	train-rmse:0.06064	valid-rmse:0.25672
# [1300]	train-rmse:0.05716	valid-rmse:0.25634
# [1400]	train-rmse:0.05381	valid-rmse:0.25601
# [1500]	train-rmse:0.05082	valid-rmse:0.25566
# [1600]	train-rmse:0.04817	valid-rmse:0.25547
# [1700]	train-rmse:0.04584	valid-rmse:0.25546
# [1800]	train-rmse:0.04360	valid-rmse:0.25532
# [1900]	train-rmse:0.04155	valid-rmse:0.25523
# [2000]	train-rmse:0.03964	valid-rmse:0.25506
# [2100]	train-rmse:0.03791	valid-rmse:0.25488
# [2200]	train-rmse:0.03640	valid-rmse:0.25480
# [2300]	train-rmse:0.03489	valid-rmse:0.25473
# [2400]	train-rmse:0.03350	valid-rmse:0.25463
# [2500]	train-rmse:0.03223	valid-rmse:0.25450
# [2600]	train-rmse:0.03106	valid-rmse:0.25442
# [2700]	train-rmse:0.02987	valid-rmse:0.25435
# [2800]	train-rmse:0.02883	valid-rmse:0.25435
# [2900]	train-rmse:0.02783	valid-rmse:0.25433
# [3000]	train-rmse:0.02690	valid-rmse:0.25425
# [3100]	train-rmse:0.02604	valid-rmse:0.25423
# [3200]	train-rmse:0.02520	valid-rmse:0.25419
# [3300]	train-rmse:0.02437	valid-rmse:0.25419
# [3400]	train-rmse:0.02359	valid-rmse:0.25425
# [3499]	train-rmse:0.02285	valid-rmse:0.25423
# FOLD RMSE = 0.2542268350629221
# Fold: 2.0
# Iteration: 1
# [0]	train-rmse:1.14733	valid-rmse:1.17435
# [100]	train-rmse:0.19277	valid-rmse:0.31119
# [200]	train-rmse:0.15355	valid-rmse:0.30033
# [300]	train-rmse:0.12989	valid-rmse:0.29456
# [400]	train-rmse:0.11277	valid-rmse:0.29199
# [500]	train-rmse:0.10030	valid-rmse:0.28953
# [600]	train-rmse:0.09033	valid-rmse:0.28849
# [700]	train-rmse:0.08267	valid-rmse:0.28760
# [800]	train-rmse:0.07596	valid-rmse:0.28715
# [900]	train-rmse:0.07009	valid-rmse:0.28655
# [1000]	train-rmse:0.06487	valid-rmse:0.28604
# [1100]	train-rmse:0.06044	valid-rmse:0.28579
# [1200]	train-rmse:0.05647	valid-rmse:0.28536
# [1300]	train-rmse:0.05297	valid-rmse:0.28503
# [1400]	train-rmse:0.04987	valid-rmse:0.28450
# [1500]	train-rmse:0.04722	valid-rmse:0.28428
# [1600]	train-rmse:0.04482	valid-rmse:0.28416
# [1700]	train-rmse:0.04265	valid-rmse:0.28390
# [1800]	train-rmse:0.04054	valid-rmse:0.28376
# [1900]	train-rmse:0.03877	valid-rmse:0.28382
# [2000]	train-rmse:0.03713	valid-rmse:0.28370
# [2100]	train-rmse:0.03557	valid-rmse:0.28354
# [2200]	train-rmse:0.03412	valid-rmse:0.28347
# [2300]	train-rmse:0.03271	valid-rmse:0.28341
# [2400]	train-rmse:0.03147	valid-rmse:0.28329
# [2500]	train-rmse:0.03023	valid-rmse:0.28320
# [2600]	train-rmse:0.02913	valid-rmse:0.28317
# [2700]	train-rmse:0.02810	valid-rmse:0.28307
# [2800]	train-rmse:0.02712	valid-rmse:0.28303
# [2900]	train-rmse:0.02616	valid-rmse:0.28297
# [3000]	train-rmse:0.02528	valid-rmse:0.28296
# [3100]	train-rmse:0.02443	valid-rmse:0.28290
# [3200]	train-rmse:0.02364	valid-rmse:0.28283
# [3300]	train-rmse:0.02288	valid-rmse:0.28286
# [3400]	train-rmse:0.02214	valid-rmse:0.28280
# [3500]	train-rmse:0.02146	valid-rmse:0.28280
# [3600]	train-rmse:0.02079	valid-rmse:0.28277
# [3700]	train-rmse:0.02015	valid-rmse:0.28272
# [3800]	train-rmse:0.01953	valid-rmse:0.28269
# [3900]	train-rmse:0.01897	valid-rmse:0.28267
# [4000]	train-rmse:0.01842	valid-rmse:0.28268
# [4050]	train-rmse:0.01815	valid-rmse:0.28270
# FOLD RMSE = 0.28270082388592976
# Fold: 3.0
# Iteration: 1
# [0]	train-rmse:1.13438	valid-rmse:1.22864
# [100]	train-rmse:0.20273	valid-rmse:0.27233
# [200]	train-rmse:0.16200	valid-rmse:0.26454
# [300]	train-rmse:0.13545	valid-rmse:0.25866
# [400]	train-rmse:0.11768	valid-rmse:0.25639
# [500]	train-rmse:0.10565	valid-rmse:0.25544
# [600]	train-rmse:0.09562	valid-rmse:0.25482
# [700]	train-rmse:0.08728	valid-rmse:0.25444
# [800]	train-rmse:0.08046	valid-rmse:0.25446
# [900]	train-rmse:0.07478	valid-rmse:0.25420
# [1000]	train-rmse:0.06925	valid-rmse:0.25371
# [1100]	train-rmse:0.06414	valid-rmse:0.25358
# [1200]	train-rmse:0.06008	valid-rmse:0.25311
# [1300]	train-rmse:0.05637	valid-rmse:0.25289
# [1400]	train-rmse:0.05303	valid-rmse:0.25284
# [1500]	train-rmse:0.05003	valid-rmse:0.25265
# [1600]	train-rmse:0.04734	valid-rmse:0.25252
# [1700]	train-rmse:0.04500	valid-rmse:0.25265
# [1800]	train-rmse:0.04286	valid-rmse:0.25254
# [1900]	train-rmse:0.04088	valid-rmse:0.25233
# [2000]	train-rmse:0.03905	valid-rmse:0.25234
# [2100]	train-rmse:0.03737	valid-rmse:0.25230
# [2200]	train-rmse:0.03580	valid-rmse:0.25221
# [2300]	train-rmse:0.03430	valid-rmse:0.25214
# [2400]	train-rmse:0.03296	valid-rmse:0.25202
# [2500]	train-rmse:0.03174	valid-rmse:0.25198
# [2600]	train-rmse:0.03058	valid-rmse:0.25200
# [2700]	train-rmse:0.02950	valid-rmse:0.25202
# [2709]	train-rmse:0.02939	valid-rmse:0.25202
# FOLD RMSE = 0.2520154389106092
# Fold: 4.0
# Iteration: 1
# [0]	train-rmse:1.17592	valid-rmse:1.05193
# [100]	train-rmse:0.19416	valid-rmse:0.29941
# [200]	train-rmse:0.15260	valid-rmse:0.28949
# [300]	train-rmse:0.12717	valid-rmse:0.28530
# [400]	train-rmse:0.10998	valid-rmse:0.28308
# [500]	train-rmse:0.09684	valid-rmse:0.28195
# [600]	train-rmse:0.08707	valid-rmse:0.28071
# [700]	train-rmse:0.07943	valid-rmse:0.28032
# [800]	train-rmse:0.07253	valid-rmse:0.27998
# [900]	train-rmse:0.06696	valid-rmse:0.27938
# [1000]	train-rmse:0.06215	valid-rmse:0.27906
# [1100]	train-rmse:0.05799	valid-rmse:0.27911
# [1200]	train-rmse:0.05441	valid-rmse:0.27890
# [1300]	train-rmse:0.05082	valid-rmse:0.27869
# [1400]	train-rmse:0.04791	valid-rmse:0.27858
# [1500]	train-rmse:0.04546	valid-rmse:0.27858
# [1600]	train-rmse:0.04319	valid-rmse:0.27849
# [1700]	train-rmse:0.04099	valid-rmse:0.27852
# [1800]	train-rmse:0.03911	valid-rmse:0.27853
# [1831]	train-rmse:0.03856	valid-rmse:0.27846
# FOLD RMSE = 0.278445312903545
# Fold: 5.0
# Iteration: 1
# [0]	train-rmse:1.15865	valid-rmse:1.13007
# [100]	train-rmse:0.20141	valid-rmse:0.29419
# [200]	train-rmse:0.16115	valid-rmse:0.28251
# [300]	train-rmse:0.13488	valid-rmse:0.27608
# [400]	train-rmse:0.11721	valid-rmse:0.27234
# [500]	train-rmse:0.10352	valid-rmse:0.27030
# [600]	train-rmse:0.09267	valid-rmse:0.26909
# [700]	train-rmse:0.08397	valid-rmse:0.26809
# [800]	train-rmse:0.07687	valid-rmse:0.26764
# [900]	train-rmse:0.07088	valid-rmse:0.26691
# [1000]	train-rmse:0.06581	valid-rmse:0.26654
# [1100]	train-rmse:0.06090	valid-rmse:0.26654
# [1200]	train-rmse:0.05712	valid-rmse:0.26628
# [1300]	train-rmse:0.05354	valid-rmse:0.26603
# [1400]	train-rmse:0.05059	valid-rmse:0.26593
# [1500]	train-rmse:0.04790	valid-rmse:0.26584
# [1600]	train-rmse:0.04550	valid-rmse:0.26572
# [1700]	train-rmse:0.04317	valid-rmse:0.26549
# [1800]	train-rmse:0.04101	valid-rmse:0.26536
# [1900]	train-rmse:0.03919	valid-rmse:0.26527
# [2000]	train-rmse:0.03741	valid-rmse:0.26518
# [2100]	train-rmse:0.03583	valid-rmse:0.26513
# [2200]	train-rmse:0.03441	valid-rmse:0.26509
# [2300]	train-rmse:0.03303	valid-rmse:0.26510
# [2400]	train-rmse:0.03175	valid-rmse:0.26501
# [2500]	train-rmse:0.03053	valid-rmse:0.26495
# [2600]	train-rmse:0.02943	valid-rmse:0.26491
# [2700]	train-rmse:0.02838	valid-rmse:0.26491
# [2800]	train-rmse:0.02738	valid-rmse:0.26486
# [2900]	train-rmse:0.02644	valid-rmse:0.26482
# [3000]	train-rmse:0.02550	valid-rmse:0.26481
# [3100]	train-rmse:0.02461	valid-rmse:0.26477
# [3200]	train-rmse:0.02376	valid-rmse:0.26479
# [3300]	train-rmse:0.02297	valid-rmse:0.26477
# [3311]	train-rmse:0.02289	valid-rmse:0.26477
# FOLD RMSE = 0.2647640560889693
# ############################################################
# East - MEAN RMSE = 0.26643049337039504
# East - OOF RMSE = 0.26671867649587533
# [0.2542268350629221, 0.28270082388592976, 0.2520154389106092, 0.278445312903545, 0.2647640560889693]
# CPU times: user 19min 52s, sys: 24.6 s, total: 20min 17s
# Wall time: 18min 32s

# %%
all_preds = np.concatenate([north_oof_preds, east_oof_preds])
all_target = np.concatenate([train.North, train.East])

# %%
print("ALL - OOF RMSE = {}".format(np.sqrt(mean_squared_error(all_target, all_preds))))
# Out:
# ALL - OOF RMSE = 0.29767495980901054

# %%
sub_oof = pd.DataFrame({
    'Filename': train.Filename,
    'oof_north': north_oof_preds,
    'oof_east': east_oof_preds
})

sub_oof.to_csv('oof_xgb_seq_001.csv', index=False)

# %%
sub_north_test = pd.DataFrame({
    'Id': test.Filename,
    'Predicted': north_test_preds
})

sub_east_test = pd.DataFrame({
    'Id': test.Filename,
    'Predicted': east_test_preds
})

# %%
sub_north_test.Id = sub_north_test['Id'].astype(str) + ':North'
sub_east_test.Id  = sub_east_test['Id'].astype(str) + ':East'

sub_all_test = pd.concat([sub_north_test, sub_east_test])

# %%
sub_all_test[['Id', 'Predicted']].to_csv('sub_xgb_seq_001.csv', index=False)

# %%
sub_all_test
# Out:
#                                                Id  Predicted
# 0      0f57a863af3b7e5bf59a94319a408ff7.jpg:North  -0.061523
# 1      b7d4e3a6acb3b956d8b09416958e8892.jpg:North  -0.409927
# 2      9a1bd630a47dabafa6f4cab7338d01df.jpg:North  -0.536517
# 3      3f6ebf8aef0f352720bc0cb534d878b6.jpg:North  -0.615621
# 4      7e810f05bd88ff0f86dce7116b9fa527.jpg:North  -0.729940
# ...                                           ...        ...
# 55026   fc65c23ae61ce2c6fdbc637a8296d1d7.jpg:East   1.096937
# 55027   fc6c0d99ec42bad5e2d5fbb1e71c5a50.jpg:East   1.141812
# 55028   fdbb732633c6a3d32a67fc56edc7cde4.jpg:East  -0.341321
# 55029   feac1b902c7487dcbdf298bd4be75690.jpg:East  -0.540748
# 55030   ff76ffce183c11f84489bbd0a34a2fcf.jpg:East  -1.059969
#
# [110062 rows x 2 columns]
