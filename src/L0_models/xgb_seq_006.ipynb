# %%
import os
import pandas as pd
import numpy as np
import xgboost as xgb
from lightgbm.callback import early_stopping
from sklearn.model_selection import KFold, GroupKFold
from tqdm import tqdm
from sklearn.metrics import mean_squared_error
import warnings

import math
# Out:
# <style type='text/css'>
# .datatable table.frame { margin-bottom: 0; }
# .datatable table.frame thead { border-bottom: none; }
# .datatable table.frame tr.coltypes td {  color: #FFFFFF;  line-height: 6px;  padding: 0 0.5em;}
# .datatable .bool    { background: #DDDD99; }
# .datatable .object  { background: #565656; }
# .datatable .int     { background: #5D9E5D; }
# .datatable .float   { background: #4040CC; }
# .datatable .str     { background: #CC4040; }
# .datatable .time    { background: #40CC40; }
# .datatable .row_index {  background: var(--jp-border-color3);  border-right: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  font-size: 9px;}
# .datatable .frame tbody td { text-align: left; }
# .datatable .frame tr.coltypes .row_index {  background: var(--jp-border-color0);}
# .datatable th:nth-child(2) { padding-left: 12px; }
# .datatable .hellipsis {  color: var(--jp-cell-editor-border-color);}
# .datatable .vellipsis {  background: var(--jp-layout-color0);  color: var(--jp-cell-editor-border-color);}
# .datatable .na {  color: var(--jp-cell-editor-border-color);  font-size: 80%;}
# .datatable .sp {  opacity: 0.25;}
# .datatable .footer { font-size: 9px; }
# .datatable .frame_dimensions {  background: var(--jp-border-color3);  border-top: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  display: inline-block;  opacity: 0.6;  padding: 1px 10px 1px 5px;}
# </style>

# %%
pd.set_option('display.width', 1000)
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
warnings.filterwarnings('ignore')

path = os.getcwd()

# %%
train = pd.read_csv('../input/kddbr2022apk/train_sequence_fold.csv')
test = pd.read_csv('../input/kddbr2022apk/test_sequence.csv')
df = pd.concat([train, test])

features_1 = pd.read_csv('../input/kddbr2022apk/complete_04.csv')
features_1 = features_1[["Filename","w_std","w_mean","w_median","w_min","w_max","w_var","n_std","n_mean","n_median","n_min","n_max","n_var","d_std","d_mean","d_median","d_min","d_max","d_var"]]
features_1.columns = ["Filename","_w_std","_w_mean","_w_median","_w_min","_w_max","_w_var","_n_std","_n_mean","_n_median","_n_min","_n_max","_n_var","_d_std","_d_mean","_d_median","_d_min","_d_max","_d_var"]
features_2 = pd.read_csv('../input/kddbr2022apk/complete_05.csv')
features_3 = pd.read_csv('../input/kddbr2022apk/complete_06.csv')

features = pd.merge(features_1, features_2, on='Filename', how='left')
features = pd.merge(features, features_3, on='Filename', how='left')

mario_features_tr = pd.read_csv('../input/kddbr2022apk/mario_train_vec_v1.csv')
mario_features_ts = pd.read_csv('../input/kddbr2022apk/mario_test_vec_v1.csv')

mario_features = pd.concat([mario_features_tr, mario_features_ts])
mario_features2 = pd.read_csv('../input/kddbr2022apk/vecs_v3_fe.csv')

# %%
df = pd.merge(df, features, on='Filename', how='left')
df = pd.merge(df, mario_features, on='Filename', how='left')
df = pd.merge(df, mario_features2, on='Filename', how='left')

df = df.sort_values(by=['run_id', 'run_seq_id']).reset_index(drop=True)

# %%
df['sqrt_altitude'] = np.sqrt(df['Altitude'])
df['sqrt_delta'] = np.sqrt(df['Delta'])
df['sqrt_altitude_delta'] = np.sqrt(df['Altitude'] + df['Delta'])

df['pow2_altitude'] = (df['Altitude'] ** 2)
df['pow2_delta'] = (df['Delta'] ** 2)
df['pow2_altitude_delta'] = (df['Altitude'] + df['Delta']) ** 2

df['log_Altitude'] = np.log(df['Altitude'])
df['log_Delta'] = np.log(df['Delta'])
df['log_base_05_n_mean'] = np.log(df['base_05_n_mean'])

df['pow13_Altitude'] = df['Altitude'] ** (1/3)
df['pow13_Delta'] = df['Delta'] ** (1/3)
df['pow13_base_05_n_mean'] = df['base_05_n_mean'] ** (1/3)

tgt_columns = [
    'Delta', 'Altitude', 'log_Altitude', 'log_Delta', 'pow13_Altitude', 'pow13_Delta', 'log_base_05_n_mean', 'pow13_base_05_n_mean',
    'base_05_n_mean', '_n_mean', 'base_05_f05_H_1', 'base_05_n_median', 'base_05_n_max', 'base_05_n_min', 'base_05_f05_H_4', 'x', 'base_05_f05_H_25', 'base_05_f05_H_7', 'x_mean', 'x1_mean', 'x2_mean',
    'base_05_w_mean', '_w_mean', 'base_05_f05_W_21', 'base_05_w_median', 'base_05_w_max', 'base_05_w_min', 'base_05_f05_W_18', 'y', 'base_05_f05_W_6', 'base_05_f05_W_0', 'y_mean', 'y1_mean', 'y2_mean',
    'base_06_n_mean', 'base_06_f06_H_1', 'base_06_n_median', 'base_06_n_max',
    'base_06_w_mean', 'base_06_f06_W_21', 'base_06_w_median', 'base_06_w_max'
]

seq_win = [2,3,5,10,15,25,30,50,75]
nxt_sft_win = [1,2,3,4,5,10,15]

for col in tqdm(tgt_columns):
    for win in nxt_sft_win:
        df['shift'+str(win)+'_'+col] = df.groupby('run_id')[col].shift(win).reset_index(0,drop=True)
        df['next'+str(win)+'_'+col] = df.groupby('run_id')[col].shift(-win).reset_index(0,drop=True)
        df['seq_diff_last'+str(win)+'_'+col] = df.groupby('run_id')[col].diff(win).reset_index(0,drop=True)
        df['seq_diff_next'+str(win)+'_'+col] = df.groupby('run_id')[col].diff(-win).reset_index(0,drop=True)
    
    for win in seq_win:
        df['seq_avg_w'+str(win)+'_'+col] = df.groupby('run_id')[col].rolling(win).mean().reset_index(0,drop=True)
        df['seq_std_w'+str(win)+'_'+col] = df.groupby('run_id')[col].rolling(win).std().reset_index(0,drop=True)
        df['seq_max_w'+str(win)+'_'+col] = df.groupby('run_id')[col].rolling(win).max().reset_index(0,drop=True)
        df['seq_min_w'+str(win)+'_'+col] = df.groupby('run_id')[col].rolling(win).min().reset_index(0,drop=True)
    
    
    df['seq_div_last1_'+col] = df[col] / df['shift1_'+col]
    df['seq_div_next1_'+col] = df[col] / df['next1_'+col]
    df['seq_div_last2_'+col] = df[col] / df['shift2_'+col]
    df['seq_div_next2_'+col] = df[col] / df['next2_'+col]
    df['seq_div_last3_'+col] = df[col] / df['shift3_'+col]
    df['seq_div_next3_'+col] = df[col] / df['next3_'+col]
    
    df['seq_min_'+col] = df.groupby('run_id')[col].transform('min')
    df['seq_max_'+col] = df.groupby('run_id')[col].transform('max')
    df['seq_std_'+col] = df.groupby('run_id')[col].transform('std')
    df['seq_avg_'+col] = df.groupby('run_id')[col].transform('mean')

df['r_vetorial_now'] = (df['base_05_n_mean'] ** 2) + (df['base_05_w_mean'] ** 2)
df['shift_r_vetorial'] = (df['shift1_base_05_n_mean'] ** 2) + (df['shift1_base_05_w_mean'] ** 2)
df['shift2_r_vetorial'] = (df['shift2_base_05_n_mean'] ** 2) + (df['shift2_base_05_w_mean'] ** 2)
df['next_r_vetorial'] = (df['next1_base_05_n_mean'] ** 2) + (df['next1_base_05_w_mean'] ** 2)
df['next2_r_vetorial'] = (df['next2_base_05_n_mean'] ** 2) + (df['next2_base_05_w_mean'] ** 2)
df['avg_shift_r_vet'] = (df['r_vetorial_now'] + df['shift_r_vetorial'] + df['shift2_r_vetorial']) / 3
df['avg_next_r_vet'] = (df['r_vetorial_now'] + df['next_r_vetorial'] + df['next2_r_vetorial']) / 3
df['avg_all_r_vet'] = (df['r_vetorial_now'] + df['next_r_vetorial'] + df['next2_r_vetorial'] + df['shift_r_vetorial'] + df['shift2_r_vetorial']) / 5

df['div_r_next2_next'] = df['next2_r_vetorial'] / df['next_r_vetorial']
df['div_r_next_now'] = df['next_r_vetorial'] / df['r_vetorial_now']
df['div_r_now_shift'] = df['r_vetorial_now'] / df['shift_r_vetorial']
df['div_r_shift1_shift2'] = df['shift_r_vetorial'] / df['shift2_r_vetorial']
df['avg_div_r'] = (df['div_r_next2_next'] + df['div_r_next_now'] + df['div_r_now_shift'] + df['div_r_shift1_shift2']) / 4
# Out:
# 100%|██████████| 42/42 [05:22<00:00,  7.68s/it]

# %%
print(df.shape)
# Out:
# (146262, 3301)

# %%
train = df.loc[~df.North.isnull(), :].sort_values(by=['run_id', 'run_seq_id']).reset_index(drop=True)
test = df.loc[df.North.isnull(), :].sort_values(by=['run_id', 'run_seq_id']).reset_index(drop=True)

# %%
import gc
del df
gc.collect()
# Out:
# 21

# %%
train_columns = [col for col in train.columns if col not in ['Filename', 'North', 'East', 'fold', 'run_id', 'run_seq_id']]

# %%
n_folds = 5

north_oof_preds = np.zeros(len(train))
east_oof_preds = np.zeros(len(train))

north_test_preds = np.zeros(len(test))
east_test_preds = np.zeros(len(test))

targets = ['North', 'East']

# %%
train = train.replace([np.inf, -np.inf], np.nan)
#trn_x = trn_x.fillna(-999)
test = test.replace([np.inf, -np.inf], np.nan)

# %%
# %%time
for target in targets:
    y = train[target]
    oof_preds = np.zeros(len(train))
    test_preds_fold = np.zeros(len(test))
    score_folds  = []

    # folds = GroupKFold(n_splits=n_folds)
    # for fold_, (trn_, val_) in enumerate(folds.split(y, y, train.run_id)):
    for fold_ in train.fold.sort_values().unique():
        print("Fold: {}".format(fold_))

        trn_ = train.loc[train.fold != fold_].index
        val_ = train.loc[train.fold == fold_].index

        trn_x, trn_y = train.loc[trn_, train_columns], y.loc[trn_]
        val_x, val_y = train.loc[val_, train_columns], y.loc[val_]
        
        dtrain = xgb.DMatrix(trn_x, trn_y)
        dvalid = xgb.DMatrix(val_x, val_y)
        
        watchlist = [(dtrain, 'train'), (dvalid, 'valid')]
        
        params = {
          'objective': "reg:squarederror", #"reg:logistic",
          'booster': "gbtree",
          'eval_metric': 'rmse', 
          'colsample_bytree': 0.85,
          'subsample': 0.85,
          'eta': 0.1,
          'max_depth': 5,
          'min_child_weight': 64, 
          'max_bin': 32,
          'nthread':-1,
          'seed': 99,
          'tree_method': 'gpu_hist'
        }
        
        execs = 3
        preds = np.zeros(len(val_x))
        test_preds_exec = np.zeros(len(test))
        
        for p in range(0,execs):
            print("Iteration: {}".format(p+1))
            params['seed'] += p
            model = xgb.train(params, dtrain, 
                               10000, watchlist, 
                               maximize=False, 
                               early_stopping_rounds = 200, 
                               verbose_eval=200)
                            #early_stopping_rounds = 1000)
            
            preds += ((model.predict(xgb.DMatrix(val_x))) / execs)
            test_preds_exec += ((model.predict(xgb.DMatrix(test[train_columns]))) / execs)

        test_preds_fold += (test_preds_exec / n_folds)
        oof_preds[val_] = preds
        score_folds.append(np.sqrt(mean_squared_error(val_y, preds)))
        print("FOLD RMSE = {}".format(np.sqrt(mean_squared_error(val_y, preds))))
        del dtrain, dvalid, trn_x, val_x, model
        gc.collect()

    print("############################################################")
    print("{} - MEAN RMSE = {}".format(target, np.mean(score_folds)))
    print("{} - OOF RMSE = {}".format(target, np.sqrt(mean_squared_error(y, oof_preds))))
    print(score_folds)

    if target == 'North':
        north_oof_preds = oof_preds
        north_test_preds = test_preds_fold
    else:
        east_oof_preds = oof_preds
        east_test_preds = test_preds_fold
# Out:
# Fold: 1.0
# Iteration: 1
# [0]	train-rmse:1.17932	valid-rmse:1.17017
# [200]	train-rmse:0.18059	valid-rmse:0.26761
# [400]	train-rmse:0.14212	valid-rmse:0.26080
# [600]	train-rmse:0.11875	valid-rmse:0.25798
# [800]	train-rmse:0.10293	valid-rmse:0.25720
# [1000]	train-rmse:0.09046	valid-rmse:0.25585
# [1200]	train-rmse:0.08043	valid-rmse:0.25503
# [1400]	train-rmse:0.07251	valid-rmse:0.25437
# [1600]	train-rmse:0.06564	valid-rmse:0.25403
# [1800]	train-rmse:0.05985	valid-rmse:0.25336
# [2000]	train-rmse:0.05445	valid-rmse:0.25315
# [2200]	train-rmse:0.05021	valid-rmse:0.25271
# [2400]	train-rmse:0.04623	valid-rmse:0.25231
# [2600]	train-rmse:0.04266	valid-rmse:0.25217
# [2800]	train-rmse:0.03959	valid-rmse:0.25203
# [3000]	train-rmse:0.03682	valid-rmse:0.25194
# [3200]	train-rmse:0.03439	valid-rmse:0.25188
# [3400]	train-rmse:0.03194	valid-rmse:0.25177
# [3600]	train-rmse:0.02987	valid-rmse:0.25168
# [3800]	train-rmse:0.02796	valid-rmse:0.25164
# [4000]	train-rmse:0.02618	valid-rmse:0.25155
# [4200]	train-rmse:0.02460	valid-rmse:0.25142
# [4400]	train-rmse:0.02308	valid-rmse:0.25138
# [4600]	train-rmse:0.02172	valid-rmse:0.25137
# [4730]	train-rmse:0.02092	valid-rmse:0.25139
# Iteration: 2
# [0]	train-rmse:1.17929	valid-rmse:1.17011
# [200]	train-rmse:0.17975	valid-rmse:0.26601
# [400]	train-rmse:0.14224	valid-rmse:0.26032
# [600]	train-rmse:0.11857	valid-rmse:0.25679
# [800]	train-rmse:0.10251	valid-rmse:0.25553
# [1000]	train-rmse:0.09032	valid-rmse:0.25407
# [1200]	train-rmse:0.08091	valid-rmse:0.25324
# [1400]	train-rmse:0.07282	valid-rmse:0.25270
# [1600]	train-rmse:0.06636	valid-rmse:0.25229
# [1800]	train-rmse:0.06065	valid-rmse:0.25200
# [2000]	train-rmse:0.05554	valid-rmse:0.25162
# [2200]	train-rmse:0.05104	valid-rmse:0.25137
# [2400]	train-rmse:0.04690	valid-rmse:0.25136
# [2600]	train-rmse:0.04343	valid-rmse:0.25116
# [2800]	train-rmse:0.04022	valid-rmse:0.25096
# [3000]	train-rmse:0.03724	valid-rmse:0.25082
# [3200]	train-rmse:0.03467	valid-rmse:0.25067
# [3400]	train-rmse:0.03251	valid-rmse:0.25056
# [3600]	train-rmse:0.03035	valid-rmse:0.25048
# [3800]	train-rmse:0.02839	valid-rmse:0.25042
# [4000]	train-rmse:0.02667	valid-rmse:0.25030
# [4200]	train-rmse:0.02507	valid-rmse:0.25033
# [4400]	train-rmse:0.02363	valid-rmse:0.25025
# [4600]	train-rmse:0.02222	valid-rmse:0.25023
# [4800]	train-rmse:0.02091	valid-rmse:0.25022
# [5000]	train-rmse:0.01975	valid-rmse:0.25018
# [5200]	train-rmse:0.01859	valid-rmse:0.25020
# [5214]	train-rmse:0.01850	valid-rmse:0.25019
# Iteration: 3
# [0]	train-rmse:1.17932	valid-rmse:1.17089
# [200]	train-rmse:0.18014	valid-rmse:0.26444
# [400]	train-rmse:0.14168	valid-rmse:0.25790
# [600]	train-rmse:0.11842	valid-rmse:0.25523
# [800]	train-rmse:0.10133	valid-rmse:0.25378
# [1000]	train-rmse:0.08954	valid-rmse:0.25250
# [1200]	train-rmse:0.07936	valid-rmse:0.25186
# [1400]	train-rmse:0.07149	valid-rmse:0.25159
# [1600]	train-rmse:0.06459	valid-rmse:0.25090
# [1800]	train-rmse:0.05866	valid-rmse:0.25069
# [2000]	train-rmse:0.05341	valid-rmse:0.25016
# [2200]	train-rmse:0.04912	valid-rmse:0.24995
# [2400]	train-rmse:0.04531	valid-rmse:0.24976
# [2600]	train-rmse:0.04202	valid-rmse:0.24944
# [2800]	train-rmse:0.03877	valid-rmse:0.24918
# [3000]	train-rmse:0.03600	valid-rmse:0.24897
# [3200]	train-rmse:0.03363	valid-rmse:0.24877
# [3400]	train-rmse:0.03145	valid-rmse:0.24866
# [3600]	train-rmse:0.02943	valid-rmse:0.24852
# [3800]	train-rmse:0.02763	valid-rmse:0.24844
# [4000]	train-rmse:0.02594	valid-rmse:0.24841
# [4200]	train-rmse:0.02429	valid-rmse:0.24843
# [4223]	train-rmse:0.02411	valid-rmse:0.24843
# FOLD RMSE = 0.24329802623903324
# Fold: 2.0
# Iteration: 1
# [0]	train-rmse:1.16516	valid-rmse:1.23050
# [200]	train-rmse:0.16867	valid-rmse:0.31752
# [400]	train-rmse:0.12802	valid-rmse:0.31110
# [600]	train-rmse:0.10320	valid-rmse:0.30648
# [800]	train-rmse:0.08717	valid-rmse:0.30372
# [1000]	train-rmse:0.07488	valid-rmse:0.30190
# [1200]	train-rmse:0.06493	valid-rmse:0.30065
# [1400]	train-rmse:0.05723	valid-rmse:0.29964
# [1600]	train-rmse:0.05097	valid-rmse:0.29870
# [1800]	train-rmse:0.04608	valid-rmse:0.29828
# [2000]	train-rmse:0.04220	valid-rmse:0.29774
# [2200]	train-rmse:0.03879	valid-rmse:0.29717
# [2400]	train-rmse:0.03596	valid-rmse:0.29703
# [2600]	train-rmse:0.03349	valid-rmse:0.29686
# [2800]	train-rmse:0.03130	valid-rmse:0.29658
# [3000]	train-rmse:0.02913	valid-rmse:0.29646
# [3200]	train-rmse:0.02731	valid-rmse:0.29643
# [3272]	train-rmse:0.02667	valid-rmse:0.29640
# Iteration: 2
# [0]	train-rmse:1.16484	valid-rmse:1.23496
# [200]	train-rmse:0.16801	valid-rmse:0.31161
# [400]	train-rmse:0.12744	valid-rmse:0.30411
# [600]	train-rmse:0.10406	valid-rmse:0.30081
# [800]	train-rmse:0.08750	valid-rmse:0.29928
# [1000]	train-rmse:0.07586	valid-rmse:0.29882
# [1200]	train-rmse:0.06651	valid-rmse:0.29828
# [1400]	train-rmse:0.05846	valid-rmse:0.29757
# [1600]	train-rmse:0.05224	valid-rmse:0.29706
# [1800]	train-rmse:0.04701	valid-rmse:0.29680
# [2000]	train-rmse:0.04277	valid-rmse:0.29636
# [2200]	train-rmse:0.03929	valid-rmse:0.29604
# [2400]	train-rmse:0.03620	valid-rmse:0.29566
# [2600]	train-rmse:0.03362	valid-rmse:0.29561
# [2800]	train-rmse:0.03121	valid-rmse:0.29542
# [3000]	train-rmse:0.02932	valid-rmse:0.29532
# [3200]	train-rmse:0.02738	valid-rmse:0.29520
# [3400]	train-rmse:0.02577	valid-rmse:0.29515
# [3600]	train-rmse:0.02434	valid-rmse:0.29521
# [3622]	train-rmse:0.02419	valid-rmse:0.29517
# Iteration: 3
# [0]	train-rmse:1.16494	valid-rmse:1.23146
# [200]	train-rmse:0.16663	valid-rmse:0.31294
# [400]	train-rmse:0.12772	valid-rmse:0.30603
# [600]	train-rmse:0.10342	valid-rmse:0.30212
# [800]	train-rmse:0.08700	valid-rmse:0.29941
# [1000]	train-rmse:0.07443	valid-rmse:0.29725
# [1200]	train-rmse:0.06469	valid-rmse:0.29619
# [1400]	train-rmse:0.05728	valid-rmse:0.29546
# [1600]	train-rmse:0.05134	valid-rmse:0.29478
# [1800]	train-rmse:0.04632	valid-rmse:0.29389
# [2000]	train-rmse:0.04224	valid-rmse:0.29357
# [2200]	train-rmse:0.03875	valid-rmse:0.29311
# [2380]	train-rmse:0.03614	valid-rmse:0.29309
# FOLD RMSE = 0.28781182531231797
# Fold: 3.0
# Iteration: 1
# [0]	train-rmse:1.18799	valid-rmse:1.13314
# [200]	train-rmse:0.18451	valid-rmse:0.27434
# [400]	train-rmse:0.14822	valid-rmse:0.26977
# [600]	train-rmse:0.12559	valid-rmse:0.26763
# [800]	train-rmse:0.10913	valid-rmse:0.26590
# [1000]	train-rmse:0.09612	valid-rmse:0.26518
# [1200]	train-rmse:0.08599	valid-rmse:0.26447
# [1400]	train-rmse:0.07771	valid-rmse:0.26443
# [1600]	train-rmse:0.07063	valid-rmse:0.26464
# [1642]	train-rmse:0.06939	valid-rmse:0.26465
# Iteration: 2
# [0]	train-rmse:1.18807	valid-rmse:1.13170
# [200]	train-rmse:0.18670	valid-rmse:0.28087
# [400]	train-rmse:0.15146	valid-rmse:0.27508
# [600]	train-rmse:0.12801	valid-rmse:0.27352
# [800]	train-rmse:0.11128	valid-rmse:0.27238
# [1000]	train-rmse:0.09862	valid-rmse:0.27205
# [1200]	train-rmse:0.08849	valid-rmse:0.27106
# [1400]	train-rmse:0.08073	valid-rmse:0.27036
# [1600]	train-rmse:0.07394	valid-rmse:0.26968
# [1800]	train-rmse:0.06813	valid-rmse:0.26953
# [2000]	train-rmse:0.06300	valid-rmse:0.26922
# [2200]	train-rmse:0.05861	valid-rmse:0.26923
# [2222]	train-rmse:0.05811	valid-rmse:0.26912
# Iteration: 3
# [0]	train-rmse:1.18803	valid-rmse:1.13197
# [200]	train-rmse:0.18657	valid-rmse:0.27934
# [400]	train-rmse:0.15187	valid-rmse:0.27312
# [600]	train-rmse:0.12951	valid-rmse:0.27030
# [800]	train-rmse:0.11319	valid-rmse:0.26957
# [1000]	train-rmse:0.10026	valid-rmse:0.26906
# [1200]	train-rmse:0.08986	valid-rmse:0.26818
# [1400]	train-rmse:0.08134	valid-rmse:0.26803
# [1446]	train-rmse:0.07961	valid-rmse:0.26804
# FOLD RMSE = 0.26106484948903785
# Fold: 4.0
# Iteration: 1
# [0]	train-rmse:1.17684	valid-rmse:1.17854
# [200]	train-rmse:0.12310	valid-rmse:0.44871
# [400]	train-rmse:0.09051	valid-rmse:0.44523
# [600]	train-rmse:0.07243	valid-rmse:0.44276
# [800]	train-rmse:0.06081	valid-rmse:0.44197
# [1000]	train-rmse:0.05310	valid-rmse:0.44124
# [1200]	train-rmse:0.04772	valid-rmse:0.44080
# [1400]	train-rmse:0.04334	valid-rmse:0.44059
# [1600]	train-rmse:0.03993	valid-rmse:0.44038
# [1800]	train-rmse:0.03690	valid-rmse:0.44022
# [2000]	train-rmse:0.03442	valid-rmse:0.44012
# [2107]	train-rmse:0.03317	valid-rmse:0.44012
# Iteration: 2
# [0]	train-rmse:1.17691	valid-rmse:1.17909
# [200]	train-rmse:0.12213	valid-rmse:0.45038
# [400]	train-rmse:0.08913	valid-rmse:0.44561
# [600]	train-rmse:0.07231	valid-rmse:0.44352
# [800]	train-rmse:0.06092	valid-rmse:0.44217
# [1000]	train-rmse:0.05298	valid-rmse:0.44150
# [1200]	train-rmse:0.04721	valid-rmse:0.44084
# [1400]	train-rmse:0.04269	valid-rmse:0.44062
# [1600]	train-rmse:0.03925	valid-rmse:0.44024
# [1800]	train-rmse:0.03636	valid-rmse:0.44016
# [2000]	train-rmse:0.03374	valid-rmse:0.44005
# [2200]	train-rmse:0.03168	valid-rmse:0.43997
# [2400]	train-rmse:0.02979	valid-rmse:0.43992
# [2600]	train-rmse:0.02806	valid-rmse:0.43984
# [2800]	train-rmse:0.02659	valid-rmse:0.43980
# [2861]	train-rmse:0.02612	valid-rmse:0.43980
# Iteration: 3
# [0]	train-rmse:1.17704	valid-rmse:1.17477
# [200]	train-rmse:0.12271	valid-rmse:0.45280
# [400]	train-rmse:0.08949	valid-rmse:0.44824
# [600]	train-rmse:0.07196	valid-rmse:0.44620
# [800]	train-rmse:0.06120	valid-rmse:0.44498
# [1000]	train-rmse:0.05338	valid-rmse:0.44408
# [1200]	train-rmse:0.04749	valid-rmse:0.44321
# [1400]	train-rmse:0.04327	valid-rmse:0.44287
# [1600]	train-rmse:0.03958	valid-rmse:0.44263
# [1800]	train-rmse:0.03637	valid-rmse:0.44244
# [2000]	train-rmse:0.03380	valid-rmse:0.44229
# [2200]	train-rmse:0.03167	valid-rmse:0.44227
# [2400]	train-rmse:0.02986	valid-rmse:0.44214
# [2600]	train-rmse:0.02816	valid-rmse:0.44213
# [2743]	train-rmse:0.02706	valid-rmse:0.44210
# FOLD RMSE = 0.4375866378426187
# Fold: 5.0
# Iteration: 1
# [0]	train-rmse:1.17794	valid-rmse:1.17730
# [200]	train-rmse:0.16963	valid-rmse:0.29331
# [400]	train-rmse:0.13009	valid-rmse:0.28920
# [600]	train-rmse:0.10666	valid-rmse:0.28777
# [800]	train-rmse:0.08950	valid-rmse:0.28727
# [1000]	train-rmse:0.07746	valid-rmse:0.28672
# [1200]	train-rmse:0.06751	valid-rmse:0.28623
# [1367]	train-rmse:0.06077	valid-rmse:0.28633
# Iteration: 2
# [0]	train-rmse:1.17776	valid-rmse:1.17741
# [200]	train-rmse:0.16953	valid-rmse:0.28721
# [400]	train-rmse:0.12903	valid-rmse:0.28134
# [600]	train-rmse:0.10527	valid-rmse:0.27964
# [800]	train-rmse:0.08886	valid-rmse:0.27788
# [1000]	train-rmse:0.07620	valid-rmse:0.27743
# [1200]	train-rmse:0.06680	valid-rmse:0.27688
# [1400]	train-rmse:0.05898	valid-rmse:0.27645
# [1600]	train-rmse:0.05276	valid-rmse:0.27619
# [1800]	train-rmse:0.04752	valid-rmse:0.27594
# [2000]	train-rmse:0.04330	valid-rmse:0.27589
# [2200]	train-rmse:0.03964	valid-rmse:0.27580
# [2400]	train-rmse:0.03664	valid-rmse:0.27577
# [2600]	train-rmse:0.03394	valid-rmse:0.27575
# [2800]	train-rmse:0.03159	valid-rmse:0.27565
# [3000]	train-rmse:0.02958	valid-rmse:0.27560
# [3200]	train-rmse:0.02779	valid-rmse:0.27561
# [3263]	train-rmse:0.02721	valid-rmse:0.27559
# Iteration: 3
# [0]	train-rmse:1.17789	valid-rmse:1.17726
# [200]	train-rmse:0.16941	valid-rmse:0.28654
# [400]	train-rmse:0.12966	valid-rmse:0.28298
# [600]	train-rmse:0.10562	valid-rmse:0.28122
# [800]	train-rmse:0.08888	valid-rmse:0.27939
# [1000]	train-rmse:0.07637	valid-rmse:0.27853
# [1200]	train-rmse:0.06647	valid-rmse:0.27806
# [1400]	train-rmse:0.05866	valid-rmse:0.27744
# [1600]	train-rmse:0.05265	valid-rmse:0.27740
# [1695]	train-rmse:0.05014	valid-rmse:0.27732
# FOLD RMSE = 0.2740573325977341
# ############################################################
# North - MEAN RMSE = 0.3007637342961484
# North - OOF RMSE = 0.3087950573891418
# [0.24329802623903324, 0.28781182531231797, 0.26106484948903785, 0.4375866378426187, 0.2740573325977341]
# Fold: 1.0
# Iteration: 1
# [0]	train-rmse:1.14653	valid-rmse:1.17495
# [200]	train-rmse:0.12736	valid-rmse:0.24311
# [400]	train-rmse:0.09621	valid-rmse:0.23778
# [600]	train-rmse:0.07901	valid-rmse:0.23548
# [800]	train-rmse:0.06713	valid-rmse:0.23447
# [1000]	train-rmse:0.05851	valid-rmse:0.23370
# [1200]	train-rmse:0.05185	valid-rmse:0.23330
# [1400]	train-rmse:0.04674	valid-rmse:0.23302
# [1600]	train-rmse:0.04253	valid-rmse:0.23264
# [1800]	train-rmse:0.03881	valid-rmse:0.23230
# [2000]	train-rmse:0.03577	valid-rmse:0.23215
# [2121]	train-rmse:0.03403	valid-rmse:0.23213
# Iteration: 2
# [0]	train-rmse:1.14715	valid-rmse:1.17421
# [200]	train-rmse:0.12837	valid-rmse:0.25262
# [400]	train-rmse:0.09566	valid-rmse:0.24662
# [600]	train-rmse:0.07814	valid-rmse:0.24411
# [800]	train-rmse:0.06641	valid-rmse:0.24365
# [1000]	train-rmse:0.05837	valid-rmse:0.24294
# [1200]	train-rmse:0.05201	valid-rmse:0.24252
# [1400]	train-rmse:0.04667	valid-rmse:0.24231
# [1600]	train-rmse:0.04241	valid-rmse:0.24205
# [1800]	train-rmse:0.03870	valid-rmse:0.24169
# [2000]	train-rmse:0.03574	valid-rmse:0.24146
# [2200]	train-rmse:0.03301	valid-rmse:0.24137
# [2400]	train-rmse:0.03059	valid-rmse:0.24137
# [2588]	train-rmse:0.02867	valid-rmse:0.24137
# Iteration: 3
# [0]	train-rmse:1.14697	valid-rmse:1.17208
# [200]	train-rmse:0.12728	valid-rmse:0.24800
# [400]	train-rmse:0.09588	valid-rmse:0.24326
# [600]	train-rmse:0.07879	valid-rmse:0.24148
# [800]	train-rmse:0.06687	valid-rmse:0.24048
# [1000]	train-rmse:0.05835	valid-rmse:0.23999
# [1200]	train-rmse:0.05151	valid-rmse:0.23927
# [1400]	train-rmse:0.04608	valid-rmse:0.23895
# [1600]	train-rmse:0.04212	valid-rmse:0.23895
# [1630]	train-rmse:0.04157	valid-rmse:0.23896
# FOLD RMSE = 0.23127527324916364
# Fold: 2.0
# Iteration: 1
# [0]	train-rmse:1.14601	valid-rmse:1.17341
# [200]	train-rmse:0.12464	valid-rmse:0.27101
# [400]	train-rmse:0.09091	valid-rmse:0.26671
# [600]	train-rmse:0.07222	valid-rmse:0.26363
# [800]	train-rmse:0.06118	valid-rmse:0.26241
# [996]	train-rmse:0.05355	valid-rmse:0.26241
# Iteration: 2
# [0]	train-rmse:1.14592	valid-rmse:1.17410
# [200]	train-rmse:0.12658	valid-rmse:0.27225
# [400]	train-rmse:0.09090	valid-rmse:0.26783
# [600]	train-rmse:0.07264	valid-rmse:0.26535
# [800]	train-rmse:0.06111	valid-rmse:0.26433
# [1000]	train-rmse:0.05318	valid-rmse:0.26341
# [1200]	train-rmse:0.04734	valid-rmse:0.26319
# [1400]	train-rmse:0.04269	valid-rmse:0.26289
# [1600]	train-rmse:0.03882	valid-rmse:0.26238
# [1800]	train-rmse:0.03574	valid-rmse:0.26246
# [2000]	train-rmse:0.03297	valid-rmse:0.26229
# [2200]	train-rmse:0.03061	valid-rmse:0.26212
# [2400]	train-rmse:0.02853	valid-rmse:0.26215
# [2421]	train-rmse:0.02833	valid-rmse:0.26212
# Iteration: 3
# [0]	train-rmse:1.14570	valid-rmse:1.17401
# [200]	train-rmse:0.12528	valid-rmse:0.27639
# [400]	train-rmse:0.09106	valid-rmse:0.27132
# [600]	train-rmse:0.07263	valid-rmse:0.26933
# [800]	train-rmse:0.06102	valid-rmse:0.26917
# [1000]	train-rmse:0.05321	valid-rmse:0.26868
# [1200]	train-rmse:0.04717	valid-rmse:0.26836
# [1275]	train-rmse:0.04526	valid-rmse:0.26822
# FOLD RMSE = 0.2572070386197692
# Fold: 3.0
# Iteration: 1
# [0]	train-rmse:1.13267	valid-rmse:1.22881
# [200]	train-rmse:0.13076	valid-rmse:0.25906
# [400]	train-rmse:0.09681	valid-rmse:0.25454
# [600]	train-rmse:0.07852	valid-rmse:0.25263
# [800]	train-rmse:0.06631	valid-rmse:0.25205
# [1000]	train-rmse:0.05720	valid-rmse:0.25147
# [1200]	train-rmse:0.05091	valid-rmse:0.25099
# [1400]	train-rmse:0.04568	valid-rmse:0.25046
# [1600]	train-rmse:0.04134	valid-rmse:0.25000
# [1800]	train-rmse:0.03775	valid-rmse:0.24991
# [2000]	train-rmse:0.03477	valid-rmse:0.24975
# [2200]	train-rmse:0.03217	valid-rmse:0.24962
# [2400]	train-rmse:0.02988	valid-rmse:0.24944
# [2600]	train-rmse:0.02791	valid-rmse:0.24938
# [2768]	train-rmse:0.02641	valid-rmse:0.24939
# Iteration: 2
# [0]	train-rmse:1.13289	valid-rmse:1.22706
# [200]	train-rmse:0.13155	valid-rmse:0.26174
# [400]	train-rmse:0.09906	valid-rmse:0.25719
# [600]	train-rmse:0.08053	valid-rmse:0.25500
# [800]	train-rmse:0.06900	valid-rmse:0.25420
# [1000]	train-rmse:0.06074	valid-rmse:0.25351
# [1200]	train-rmse:0.05391	valid-rmse:0.25347
# [1400]	train-rmse:0.04865	valid-rmse:0.25311
# [1600]	train-rmse:0.04413	valid-rmse:0.25284
# [1800]	train-rmse:0.04043	valid-rmse:0.25261
# [2000]	train-rmse:0.03713	valid-rmse:0.25241
# [2200]	train-rmse:0.03428	valid-rmse:0.25222
# [2400]	train-rmse:0.03184	valid-rmse:0.25221
# [2583]	train-rmse:0.02967	valid-rmse:0.25221
# Iteration: 3
# [0]	train-rmse:1.13284	valid-rmse:1.23069
# [200]	train-rmse:0.13042	valid-rmse:0.25525
# [400]	train-rmse:0.09860	valid-rmse:0.25049
# [600]	train-rmse:0.08158	valid-rmse:0.24930
# [800]	train-rmse:0.06947	valid-rmse:0.24842
# [1000]	train-rmse:0.06036	valid-rmse:0.24811
# [1200]	train-rmse:0.05340	valid-rmse:0.24791
# [1400]	train-rmse:0.04783	valid-rmse:0.24742
# [1600]	train-rmse:0.04332	valid-rmse:0.24707
# [1800]	train-rmse:0.03964	valid-rmse:0.24666
# [2000]	train-rmse:0.03648	valid-rmse:0.24656
# [2200]	train-rmse:0.03373	valid-rmse:0.24630
# [2400]	train-rmse:0.03134	valid-rmse:0.24613
# [2600]	train-rmse:0.02926	valid-rmse:0.24595
# [2800]	train-rmse:0.02732	valid-rmse:0.24593
# [3000]	train-rmse:0.02560	valid-rmse:0.24595
# [3030]	train-rmse:0.02535	valid-rmse:0.24592
# FOLD RMSE = 0.2436071193715956
# Fold: 4.0
# Iteration: 1
# [0]	train-rmse:1.17469	valid-rmse:1.04905
# [200]	train-rmse:0.12400	valid-rmse:0.29201
# [400]	train-rmse:0.08978	valid-rmse:0.28324
# [600]	train-rmse:0.07311	valid-rmse:0.28263
# [700]	train-rmse:0.06736	valid-rmse:0.28283
# Iteration: 2
# [0]	train-rmse:1.17470	valid-rmse:1.04852
# [200]	train-rmse:0.12210	valid-rmse:0.28832
# [400]	train-rmse:0.08828	valid-rmse:0.28179
# [600]	train-rmse:0.07189	valid-rmse:0.28170
# [770]	train-rmse:0.06312	valid-rmse:0.28310
# Iteration: 3
# [0]	train-rmse:1.17443	valid-rmse:1.04847
# [200]	train-rmse:0.12211	valid-rmse:0.29078
# [400]	train-rmse:0.08916	valid-rmse:0.28460
# [600]	train-rmse:0.07184	valid-rmse:0.28238
# [800]	train-rmse:0.06117	valid-rmse:0.28176
# [1000]	train-rmse:0.05397	valid-rmse:0.28196
# [1045]	train-rmse:0.05258	valid-rmse:0.28196
# FOLD RMSE = 0.27771748363124477
# Fold: 5.0
# Iteration: 1
# [0]	train-rmse:1.15714	valid-rmse:1.13446
# [200]	train-rmse:0.12828	valid-rmse:0.28593
# [400]	train-rmse:0.09233	valid-rmse:0.28028
# [600]	train-rmse:0.07437	valid-rmse:0.27828
# [800]	train-rmse:0.06228	valid-rmse:0.27730
# [1000]	train-rmse:0.05425	valid-rmse:0.27601
# [1200]	train-rmse:0.04806	valid-rmse:0.27552
# [1400]	train-rmse:0.04324	valid-rmse:0.27506
# [1600]	train-rmse:0.03934	valid-rmse:0.27491
# [1800]	train-rmse:0.03601	valid-rmse:0.27491
# [2000]	train-rmse:0.03310	valid-rmse:0.27484
# [2200]	train-rmse:0.03072	valid-rmse:0.27480
# [2238]	train-rmse:0.03031	valid-rmse:0.27479
# Iteration: 2
# [0]	train-rmse:1.15711	valid-rmse:1.13116
# [200]	train-rmse:0.12893	valid-rmse:0.29494
# [400]	train-rmse:0.09343	valid-rmse:0.28803
# [600]	train-rmse:0.07429	valid-rmse:0.28538
# [800]	train-rmse:0.06266	valid-rmse:0.28443
# [1000]	train-rmse:0.05419	valid-rmse:0.28404
# [1147]	train-rmse:0.04933	valid-rmse:0.28404
# Iteration: 3
# [0]	train-rmse:1.15727	valid-rmse:1.13187
# [200]	train-rmse:0.12699	valid-rmse:0.29285
# [400]	train-rmse:0.09313	valid-rmse:0.28606
# [600]	train-rmse:0.07387	valid-rmse:0.28357
# [800]	train-rmse:0.06200	valid-rmse:0.28183
# [1000]	train-rmse:0.05327	valid-rmse:0.28141
# [1200]	train-rmse:0.04724	valid-rmse:0.28086
# [1400]	train-rmse:0.04253	valid-rmse:0.28057
# [1600]	train-rmse:0.03885	valid-rmse:0.28041
# [1800]	train-rmse:0.03569	valid-rmse:0.28022
# [2000]	train-rmse:0.03302	valid-rmse:0.28015
# [2200]	train-rmse:0.03072	valid-rmse:0.28007
# [2400]	train-rmse:0.02874	valid-rmse:0.27993
# [2600]	train-rmse:0.02685	valid-rmse:0.27992
# [2734]	train-rmse:0.02574	valid-rmse:0.27992
# FOLD RMSE = 0.27420513277486525
# ############################################################
# East - MEAN RMSE = 0.25680240952932765
# East - OOF RMSE = 0.2574113039041314
# [0.23127527324916364, 0.2572070386197692, 0.2436071193715956, 0.27771748363124477, 0.27420513277486525]
# CPU times: user 1h 22min 32s, sys: 1min 46s, total: 1h 24min 18s
# Wall time: 1h 17min 53s

# %%
all_preds = np.concatenate([north_oof_preds, east_oof_preds])
all_target = np.concatenate([train.North, train.East])

# %%
print("ALL - OOF RMSE = {}".format(np.sqrt(mean_squared_error(all_target, all_preds))))
# Out:
# ALL - OOF RMSE = 0.28426657106102765

# %%
sub_oof = pd.DataFrame({
    'Filename': train.Filename,
    'oof_north': north_oof_preds,
    'oof_east': east_oof_preds
})

sub_oof.to_csv('oof_xgb_seq_006.csv', index=False)

# %%
sub_north_test = pd.DataFrame({
    'Id': test.Filename,
    'Predicted': north_test_preds
})

sub_east_test = pd.DataFrame({
    'Id': test.Filename,
    'Predicted': east_test_preds
})

# %%
sub_north_test.Id = sub_north_test['Id'].astype(str) + ':North'
sub_east_test.Id  = sub_east_test['Id'].astype(str) + ':East'

sub_all_test = pd.concat([sub_north_test, sub_east_test])

# %%
sub_all_test[['Id', 'Predicted']].to_csv('sub_xgb_seq_006.csv', index=False)

# %%
sub_all_test
# Out:
#                                                Id  Predicted
# 0      0f57a863af3b7e5bf59a94319a408ff7.jpg:North  -0.285825
# 1      b7d4e3a6acb3b956d8b09416958e8892.jpg:North  -0.422196
# 2      9a1bd630a47dabafa6f4cab7338d01df.jpg:North  -0.515939
# 3      3f6ebf8aef0f352720bc0cb534d878b6.jpg:North  -0.547070
# 4      7e810f05bd88ff0f86dce7116b9fa527.jpg:North  -0.550245
# ...                                           ...        ...
# 55026   fc65c23ae61ce2c6fdbc637a8296d1d7.jpg:East   1.391654
# 55027   fc6c0d99ec42bad5e2d5fbb1e71c5a50.jpg:East   1.407989
# 55028   fdbb732633c6a3d32a67fc56edc7cde4.jpg:East  -0.616492
# 55029   feac1b902c7487dcbdf298bd4be75690.jpg:East  -0.279986
# 55030   ff76ffce183c11f84489bbd0a34a2fcf.jpg:East  -1.273830
#
# [110062 rows x 2 columns]
