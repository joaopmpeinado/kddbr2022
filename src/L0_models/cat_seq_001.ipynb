# %%
import os
import pandas as pd
import numpy as np
import catboost as cat
from lightgbm.callback import early_stopping
from sklearn.model_selection import KFold, GroupKFold
from tqdm import tqdm
from sklearn.metrics import mean_squared_error
import warnings

import math

# %%
pd.set_option('display.width', 1000)
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
warnings.filterwarnings('ignore')

path = os.getcwd()

# %%
train = pd.read_csv('../input/kddbr2022apk/train_sequence_fold.csv')
test = pd.read_csv('../input/kddbr2022apk/test_sequence.csv')
df = pd.concat([train, test])

features_1 = pd.read_csv('../input/kddbr2022apk/complete_04.csv')
features_1 = features_1[["Filename","w_std","w_mean","w_median","w_min","w_max","w_var","n_std","n_mean","n_median","n_min","n_max","n_var","d_std","d_mean","d_median","d_min","d_max","d_var"]]
features_1.columns = ["Filename","_w_std","_w_mean","_w_median","_w_min","_w_max","_w_var","_n_std","_n_mean","_n_median","_n_min","_n_max","_n_var","_d_std","_d_mean","_d_median","_d_min","_d_max","_d_var"]
features_2 = pd.read_csv('../input/kddbr2022apk/complete_05.csv')
features_3 = pd.read_csv('../input/kddbr2022apk/complete_06.csv')
features_4 = pd.read_csv('../input/kddbr2022apk/complete_12.csv')

features = pd.merge(features_1, features_2, on='Filename', how='left')
features = pd.merge(features, features_3, on='Filename', how='left')


mario_features_tr = pd.read_csv('../input/kddbr2022apk/mario_train_vec_v1.csv')
mario_features_ts = pd.read_csv('../input/kddbr2022apk/mario_test_vec_v1.csv')

mario_features = pd.concat([mario_features_tr, mario_features_ts])
mario_features2 = pd.read_csv('../input/kddbr2022apk/vecs_v3_fe.csv')

# %%
df = pd.merge(df, features, on='Filename', how='left')
df = pd.merge(df, mario_features, on='Filename', how='left')
df = pd.merge(df, mario_features2, on='Filename', how='left')
df = pd.merge(df, features_4, on='Filename', how='left')

df = df.sort_values(by=['run_id', 'run_seq_id']).reset_index(drop=True)

# %%
import gc
del features, mario_features, mario_features2, features_4, features_2, features_3, features_1
gc.collect()
# Out:
# 23

# %%
df['sqrt_altitude'] = np.sqrt(df['Altitude'])
df['sqrt_delta'] = np.sqrt(df['Delta'])
df['sqrt_altitude_delta'] = np.sqrt(df['Altitude'] + df['Delta'])

df['pow2_altitude'] = (df['Altitude'] ** 2)
df['pow2_delta'] = (df['Delta'] ** 2)
df['pow2_altitude_delta'] = (df['Altitude'] + df['Delta']) ** 2

df['log_Altitude'] = np.log(df['Altitude'])
df['log_Delta'] = np.log(df['Delta'])
df['log_base_05_n_mean'] = np.log(df['base_05_n_mean'])

df['pow13_Altitude'] = df['Altitude'] ** (1/3)
df['pow13_Delta'] = df['Delta'] ** (1/3)
df['pow13_base_05_n_mean'] = df['base_05_n_mean'] ** (1/3)

tgt_columns = [
    'Delta', 'Altitude', 'log_base_05_n_mean', 'pow13_base_05_n_mean',
    'base_05_n_mean', '_n_mean', 'base_05_f05_H_1', 'base_05_n_median', 'base_05_n_max', 'base_05_n_min', 'base_05_f05_H_4', 'x', 'base_05_f05_H_25', 'base_05_f05_H_7', 'x_mean', 'x1_mean', 'x2_mean',
    'base_05_w_mean', '_w_mean', 'base_05_f05_W_21', 'base_05_w_median', 'base_05_w_max', 'base_05_w_min', 'base_05_f05_W_18', 'y', 'base_05_f05_W_6', 'base_05_f05_W_0', 'y_mean', 'y1_mean', 'y2_mean',
    'base_06_n_mean', 'base_06_f06_H_1', 'base_06_n_median', 'base_06_n_max',
    'base_06_w_mean', 'base_06_f06_W_21', 'base_06_w_median', 'base_06_w_max',
    'base_12_x', 'base_12_y', 'base_12_distance'
]

seq_win = [2,3,5,10,15,25,30,50,75]
nxt_sft_win = [1,2,3,4,5,10,15]

for col in tqdm(tgt_columns):
    for win in nxt_sft_win:
        df['shift'+str(win)+'_'+col] = df.groupby('run_id')[col].shift(win).reset_index(0,drop=True)
        df['next'+str(win)+'_'+col] = df.groupby('run_id')[col].shift(-win).reset_index(0,drop=True)
        df['seq_diff_last'+str(win)+'_'+col] = df.groupby('run_id')[col].diff(win).reset_index(0,drop=True)
        df['seq_diff_next'+str(win)+'_'+col] = df.groupby('run_id')[col].diff(-win).reset_index(0,drop=True)
    
    for win in seq_win:
        df['seq_avg_w'+str(win)+'_'+col] = df.groupby('run_id')[col].rolling(win).mean().reset_index(0,drop=True)
        df['seq_std_w'+str(win)+'_'+col] = df.groupby('run_id')[col].rolling(win).std().reset_index(0,drop=True)
        df['seq_max_w'+str(win)+'_'+col] = df.groupby('run_id')[col].rolling(win).max().reset_index(0,drop=True)
        df['seq_min_w'+str(win)+'_'+col] = df.groupby('run_id')[col].rolling(win).min().reset_index(0,drop=True)
    
    
    df['seq_div_last1_'+col] = df[col] / df['shift1_'+col]
    df['seq_div_next1_'+col] = df[col] / df['next1_'+col]
    df['seq_div_last2_'+col] = df[col] / df['shift2_'+col]
    df['seq_div_next2_'+col] = df[col] / df['next2_'+col]
    df['seq_div_last3_'+col] = df[col] / df['shift3_'+col]
    df['seq_div_next3_'+col] = df[col] / df['next3_'+col]
    
    df['seq_min_'+col] = df.groupby('run_id')[col].transform('min')
    df['seq_max_'+col] = df.groupby('run_id')[col].transform('max')
    df['seq_std_'+col] = df.groupby('run_id')[col].transform('std')
    df['seq_avg_'+col] = df.groupby('run_id')[col].transform('mean')

df['r_vetorial_now'] = (df['base_05_n_mean'] ** 2) + (df['base_05_w_mean'] ** 2)
df['shift_r_vetorial'] = (df['shift1_base_05_n_mean'] ** 2) + (df['shift1_base_05_w_mean'] ** 2)
df['shift2_r_vetorial'] = (df['shift2_base_05_n_mean'] ** 2) + (df['shift2_base_05_w_mean'] ** 2)
df['next_r_vetorial'] = (df['next1_base_05_n_mean'] ** 2) + (df['next1_base_05_w_mean'] ** 2)
df['next2_r_vetorial'] = (df['next2_base_05_n_mean'] ** 2) + (df['next2_base_05_w_mean'] ** 2)
df['avg_shift_r_vet'] = (df['r_vetorial_now'] + df['shift_r_vetorial'] + df['shift2_r_vetorial']) / 3
df['avg_next_r_vet'] = (df['r_vetorial_now'] + df['next_r_vetorial'] + df['next2_r_vetorial']) / 3
df['avg_all_r_vet'] = (df['r_vetorial_now'] + df['next_r_vetorial'] + df['next2_r_vetorial'] + df['shift_r_vetorial'] + df['shift2_r_vetorial']) / 5

df['div_r_next2_next'] = df['next2_r_vetorial'] / df['next_r_vetorial']
df['div_r_next_now'] = df['next_r_vetorial'] / df['r_vetorial_now']
df['div_r_now_shift'] = df['r_vetorial_now'] / df['shift_r_vetorial']
df['div_r_shift1_shift2'] = df['shift_r_vetorial'] / df['shift2_r_vetorial']
df['avg_div_r'] = (df['div_r_next2_next'] + df['div_r_next_now'] + df['div_r_now_shift'] + df['div_r_shift1_shift2']) / 4
# Out:
# 100%|██████████| 41/41 [05:55<00:00,  8.66s/it]

# %%
print(df.shape)
# Out:
# (146262, 3233)

# %%
train = df.loc[~df.North.isnull(), :].sort_values(by=['run_id', 'run_seq_id']).reset_index(drop=True)
test = df.loc[df.North.isnull(), :].sort_values(by=['run_id', 'run_seq_id']).reset_index(drop=True)

# %%
import gc
del df
gc.collect()
# Out:
# 23

# %%
train_columns = [col for col in train.columns if col not in ['Filename', 'North', 'East', 'fold', 'run_id', 'run_seq_id']]

# %%
n_folds = 5

north_oof_preds = np.zeros(len(train))
east_oof_preds = np.zeros(len(train))

north_test_preds = np.zeros(len(test))
east_test_preds = np.zeros(len(test))

targets = ['North', 'East']

# %%
train = train.replace([np.inf, -np.inf], np.nan)
#trn_x = trn_x.fillna(-999)
test = test.replace([np.inf, -np.inf], np.nan)

# %%
# %%time
for target in targets:
    y = train[target]
    oof_preds = np.zeros(len(train))
    test_preds_fold = np.zeros(len(test))
    score_folds  = []

    # folds = GroupKFold(n_splits=n_folds)
    # for fold_, (trn_, val_) in enumerate(folds.split(y, y, train.run_id)):
    for fold_ in train.fold.sort_values().unique():
        print("Fold: {}".format(fold_))

        trn_ = train.loc[train.fold != fold_].index
        val_ = train.loc[train.fold == fold_].index

        trn_x, trn_y = train.loc[trn_, train_columns], y.loc[trn_]
        val_x, val_y = train.loc[val_, train_columns], y.loc[val_]

        dtrain = cat.Pool(trn_x, trn_y)
        dvalid = cat.Pool(val_x, val_y)
        
        params = {
            'loss_function':       'RMSE',
            'eval_metric':         'RMSE',
            'bootstrap_type': 'Bernoulli', 
            'learning_rate':         0.05,
            #'subsample':              0.9,
            'depth':                   10,
            #'min_data_in_leaf':        50,
            'verbose':               200,
            'task_type':            'GPU',
            'random_seed':             144
        }
        
        execs = 1
        preds = np.zeros(len(val_x))
        test_preds_exec = np.zeros(len(test))
        
        for p in range(0,execs):
            print("Iteration: {}".format(p+1))
            params['random_seed'] += p
            model = cat.train(params = params,
                              pool = dtrain,
                              eval_set = dvalid,
                              iterations = 5000,
                              early_stopping_rounds = 200)
                            #early_stopping_rounds = 1000)
            del dtrain, dvalid, trn_x
            gc.collect()
            preds += ((model.predict((val_x))) / execs)
            test_preds_exec += ((model.predict((test[train_columns]))) / execs)

        test_preds_fold += (test_preds_exec / n_folds)
        oof_preds[val_] = preds
        score_folds.append(np.sqrt(mean_squared_error(val_y, preds)))
        print("FOLD RMSE = {}".format(np.sqrt(mean_squared_error(val_y, preds))))
        del model, val_x
        gc.collect()

    print("############################################################")
    print("{} - MEAN RMSE = {}".format(target, np.mean(score_folds)))
    print("{} - OOF RMSE = {}".format(target, np.sqrt(mean_squared_error(y, oof_preds))))
    print(score_folds)

    if target == 'North':
        north_oof_preds = oof_preds
        north_test_preds = test_preds_fold
    else:
        east_oof_preds = oof_preds
        east_test_preds = test_preds_fold
# Out:
# Fold: 1.0
# Iteration: 1
# 0:	learn: 1.1376321	test: 1.1483842	best: 1.1483842 (0)	total: 175ms	remaining: 14m 34s
# 200:	learn: 0.1538453	test: 0.2605049	best: 0.2604270 (199)	total: 31.4s	remaining: 12m 30s
# 400:	learn: 0.0959169	test: 0.2479305	best: 0.2479305 (400)	total: 1m 2s	remaining: 12m 2s
# 600:	learn: 0.0696832	test: 0.2434901	best: 0.2434901 (600)	total: 1m 34s	remaining: 11m 32s
# 800:	learn: 0.0537775	test: 0.2408393	best: 0.2408393 (800)	total: 2m 7s	remaining: 11m 6s
# 1000:	learn: 0.0439850	test: 0.2397949	best: 0.2397949 (1000)	total: 2m 39s	remaining: 10m 37s
# 1200:	learn: 0.0370447	test: 0.2389924	best: 0.2389924 (1200)	total: 3m 12s	remaining: 10m 9s
# 1400:	learn: 0.0320672	test: 0.2385034	best: 0.2385034 (1400)	total: 3m 46s	remaining: 9m 41s
# 1600:	learn: 0.0282636	test: 0.2382883	best: 0.2382804 (1593)	total: 4m 20s	remaining: 9m 12s
# 1800:	learn: 0.0251918	test: 0.2381740	best: 0.2381734 (1799)	total: 4m 54s	remaining: 8m 42s
# 2000:	learn: 0.0225219	test: 0.2380715	best: 0.2380712 (1999)	total: 5m 28s	remaining: 8m 12s
# 2200:	learn: 0.0203532	test: 0.2379520	best: 0.2379520 (2200)	total: 6m 3s	remaining: 7m 41s
# 2400:	learn: 0.0185117	test: 0.2378849	best: 0.2378703 (2377)	total: 6m 37s	remaining: 7m 10s
# 2600:	learn: 0.0167610	test: 0.2378183	best: 0.2378168 (2587)	total: 7m 12s	remaining: 6m 38s
# 2800:	learn: 0.0153008	test: 0.2378180	best: 0.2378047 (2644)	total: 7m 46s	remaining: 6m 6s
# bestTest = 0.2378046976
# bestIteration = 2644
# Shrink model to first 2645 iterations.
# FOLD RMSE = 0.23780474809592345
# Fold: 2.0
# Iteration: 1
# 0:	learn: 1.1269315	test: 1.1933655	best: 1.1933655 (0)	total: 167ms	remaining: 13m 55s
# 200:	learn: 0.1581183	test: 0.3037026	best: 0.3037026 (200)	total: 30.5s	remaining: 12m 7s
# 400:	learn: 0.0978014	test: 0.2872927	best: 0.2872927 (400)	total: 1m 1s	remaining: 11m 44s
# 600:	learn: 0.0698453	test: 0.2816198	best: 0.2816198 (600)	total: 1m 33s	remaining: 11m 21s
# 800:	learn: 0.0539317	test: 0.2783242	best: 0.2783184 (797)	total: 2m 5s	remaining: 10m 56s
# 1000:	learn: 0.0438683	test: 0.2768092	best: 0.2768092 (1000)	total: 2m 37s	remaining: 10m 30s
# 1200:	learn: 0.0368795	test: 0.2759563	best: 0.2759537 (1199)	total: 3m 10s	remaining: 10m 3s
# 1400:	learn: 0.0320512	test: 0.2754298	best: 0.2754290 (1395)	total: 3m 44s	remaining: 9m 35s
# 1600:	learn: 0.0282143	test: 0.2750588	best: 0.2750575 (1599)	total: 4m 17s	remaining: 9m 7s
# 1800:	learn: 0.0250705	test: 0.2748630	best: 0.2748617 (1799)	total: 4m 51s	remaining: 8m 37s
# 2000:	learn: 0.0224404	test: 0.2746783	best: 0.2746783 (2000)	total: 5m 25s	remaining: 8m 8s
# 2200:	learn: 0.0201431	test: 0.2746080	best: 0.2746023 (2187)	total: 6m	remaining: 7m 38s
# 2400:	learn: 0.0182831	test: 0.2745078	best: 0.2745073 (2398)	total: 6m 34s	remaining: 7m 7s
# 2600:	learn: 0.0166187	test: 0.2744382	best: 0.2744382 (2600)	total: 7m 8s	remaining: 6m 35s
# 2800:	learn: 0.0151772	test: 0.2743994	best: 0.2743994 (2800)	total: 7m 43s	remaining: 6m 3s
# 3000:	learn: 0.0138098	test: 0.2743926	best: 0.2743895 (2895)	total: 8m 18s	remaining: 5m 31s
# 3200:	learn: 0.0126887	test: 0.2743847	best: 0.2743830 (3032)	total: 8m 52s	remaining: 4m 59s
# 3400:	learn: 0.0116270	test: 0.2743428	best: 0.2743422 (3399)	total: 9m 27s	remaining: 4m 26s
# 3600:	learn: 0.0107094	test: 0.2743229	best: 0.2743227 (3596)	total: 10m 2s	remaining: 3m 54s
# 3800:	learn: 0.0098421	test: 0.2743100	best: 0.2743062 (3785)	total: 10m 37s	remaining: 3m 21s
# 4000:	learn: 0.0090348	test: 0.2742831	best: 0.2742831 (4000)	total: 11m 12s	remaining: 2m 47s
# 4200:	learn: 0.0083162	test: 0.2742849	best: 0.2742785 (4098)	total: 11m 47s	remaining: 2m 14s
# bestTest = 0.2742784536
# bestIteration = 4098
# Shrink model to first 4099 iterations.
# FOLD RMSE = 0.27427847456488
# Fold: 3.0
# Iteration: 1
# 0:	learn: 1.1552569	test: 1.0764967	best: 1.0764967 (0)	total: 169ms	remaining: 14m 3s
# 200:	learn: 0.1578744	test: 0.2675586	best: 0.2675586 (200)	total: 30.7s	remaining: 12m 12s
# 400:	learn: 0.0994256	test: 0.2540759	best: 0.2540759 (400)	total: 1m 1s	remaining: 11m 49s
# 600:	learn: 0.0717690	test: 0.2488380	best: 0.2488380 (600)	total: 1m 33s	remaining: 11m 26s
# 800:	learn: 0.0557922	test: 0.2465044	best: 0.2465044 (800)	total: 2m 6s	remaining: 11m 1s
# 1000:	learn: 0.0454339	test: 0.2451687	best: 0.2451687 (1000)	total: 2m 38s	remaining: 10m 34s
# 1200:	learn: 0.0383923	test: 0.2443220	best: 0.2443220 (1200)	total: 3m 11s	remaining: 10m 6s
# 1400:	learn: 0.0334576	test: 0.2437900	best: 0.2437900 (1400)	total: 3m 45s	remaining: 9m 38s
# 1600:	learn: 0.0293596	test: 0.2433885	best: 0.2433885 (1600)	total: 4m 19s	remaining: 9m 10s
# 1800:	learn: 0.0262034	test: 0.2431547	best: 0.2431547 (1800)	total: 4m 52s	remaining: 8m 40s
# 2000:	learn: 0.0234149	test: 0.2429932	best: 0.2429932 (2000)	total: 5m 27s	remaining: 8m 10s
# 2200:	learn: 0.0211007	test: 0.2429173	best: 0.2429168 (2199)	total: 6m 1s	remaining: 7m 40s
# 2400:	learn: 0.0191166	test: 0.2428499	best: 0.2428469 (2397)	total: 6m 35s	remaining: 7m 8s
# 2600:	learn: 0.0174209	test: 0.2427918	best: 0.2427905 (2596)	total: 7m 10s	remaining: 6m 36s
# 2800:	learn: 0.0159035	test: 0.2427425	best: 0.2427423 (2799)	total: 7m 44s	remaining: 6m 4s
# 3000:	learn: 0.0145987	test: 0.2427200	best: 0.2427145 (2926)	total: 8m 18s	remaining: 5m 32s
# 3200:	learn: 0.0133797	test: 0.2426826	best: 0.2426813 (3196)	total: 8m 53s	remaining: 4m 59s
# 3400:	learn: 0.0123059	test: 0.2426696	best: 0.2426687 (3399)	total: 9m 28s	remaining: 4m 27s
# 3600:	learn: 0.0113287	test: 0.2426251	best: 0.2426236 (3594)	total: 10m 3s	remaining: 3m 54s
# 3800:	learn: 0.0104292	test: 0.2426247	best: 0.2426203 (3698)	total: 10m 38s	remaining: 3m 21s
# 4000:	learn: 0.0095973	test: 0.2426202	best: 0.2426149 (3911)	total: 11m 13s	remaining: 2m 48s
# 4200:	learn: 0.0088300	test: 0.2426130	best: 0.2426081 (4186)	total: 11m 48s	remaining: 2m 14s
# bestTest = 0.2426080871
# bestIteration = 4186
# Shrink model to first 4187 iterations.
# FOLD RMSE = 0.24260809299899022
# Fold: 4.0
# Iteration: 1
# 0:	learn: 1.1408194	test: 1.1368334	best: 1.1368334 (0)	total: 184ms	remaining: 15m 19s
# 200:	learn: 0.1311578	test: 0.4349765	best: 0.4349765 (200)	total: 33s	remaining: 13m 8s
# 400:	learn: 0.0870113	test: 0.4290071	best: 0.4290071 (400)	total: 1m 4s	remaining: 12m 20s
# 600:	learn: 0.0644141	test: 0.4266211	best: 0.4266211 (600)	total: 1m 36s	remaining: 11m 48s
# 800:	learn: 0.0514153	test: 0.4256616	best: 0.4256394 (795)	total: 2m 9s	remaining: 11m 16s
# 1000:	learn: 0.0423473	test: 0.4248988	best: 0.4248883 (991)	total: 2m 42s	remaining: 10m 47s
# 1200:	learn: 0.0360073	test: 0.4243776	best: 0.4243776 (1200)	total: 3m 15s	remaining: 10m 17s
# 1400:	learn: 0.0311493	test: 0.4241398	best: 0.4241386 (1399)	total: 3m 49s	remaining: 9m 48s
# 1600:	learn: 0.0276628	test: 0.4240429	best: 0.4240379 (1595)	total: 4m 22s	remaining: 9m 17s
# 1800:	learn: 0.0247159	test: 0.4238799	best: 0.4238797 (1798)	total: 4m 56s	remaining: 8m 46s
# 2000:	learn: 0.0221487	test: 0.4237847	best: 0.4237847 (1998)	total: 5m 31s	remaining: 8m 16s
# 2200:	learn: 0.0200329	test: 0.4237548	best: 0.4237431 (2178)	total: 6m 5s	remaining: 7m 44s
# 2400:	learn: 0.0181861	test: 0.4236953	best: 0.4236953 (2400)	total: 6m 40s	remaining: 7m 13s
# 2600:	learn: 0.0166374	test: 0.4236765	best: 0.4236664 (2570)	total: 7m 14s	remaining: 6m 40s
# bestTest = 0.4236664434
# bestIteration = 2570
# Shrink model to first 2571 iterations.
# FOLD RMSE = 0.4236664018782742
# Fold: 5.0
# Iteration: 1
# 0:	learn: 1.1386293	test: 1.1468320	best: 1.1468320 (0)	total: 165ms	remaining: 13m 46s
# 200:	learn: 0.1565436	test: 0.2900191	best: 0.2900191 (200)	total: 30.9s	remaining: 12m 18s
# 400:	learn: 0.0981503	test: 0.2771597	best: 0.2771597 (400)	total: 1m 2s	remaining: 11m 51s
# 600:	learn: 0.0702697	test: 0.2717512	best: 0.2717512 (600)	total: 1m 33s	remaining: 11m 25s
# 800:	learn: 0.0543020	test: 0.2693255	best: 0.2693247 (799)	total: 2m 5s	remaining: 10m 59s
# 1000:	learn: 0.0445605	test: 0.2681716	best: 0.2681716 (1000)	total: 2m 37s	remaining: 10m 30s
# 1200:	learn: 0.0376670	test: 0.2675285	best: 0.2675247 (1179)	total: 3m 10s	remaining: 10m 1s
# 1400:	learn: 0.0325729	test: 0.2672134	best: 0.2671814 (1393)	total: 3m 43s	remaining: 9m 33s
# 1600:	learn: 0.0286575	test: 0.2670026	best: 0.2669957 (1594)	total: 4m 16s	remaining: 9m 4s
# 1800:	learn: 0.0253969	test: 0.2668629	best: 0.2668570 (1798)	total: 4m 49s	remaining: 8m 35s
# 2000:	learn: 0.0227025	test: 0.2667817	best: 0.2667698 (1966)	total: 5m 23s	remaining: 8m 5s
# 2200:	learn: 0.0204408	test: 0.2667023	best: 0.2666994 (2190)	total: 5m 57s	remaining: 7m 34s
# 2400:	learn: 0.0184972	test: 0.2666802	best: 0.2666680 (2291)	total: 6m 31s	remaining: 7m 3s
# 2600:	learn: 0.0168382	test: 0.2667022	best: 0.2666679 (2447)	total: 7m 5s	remaining: 6m 32s
# bestTest = 0.2666678786
# bestIteration = 2447
# Shrink model to first 2448 iterations.
# FOLD RMSE = 0.2666676713079777
# ############################################################
# North - MEAN RMSE = 0.2890050777692091
# North - OOF RMSE = 0.2970661866997732
# [0.23780474809592345, 0.27427847456488, 0.24260809299899022, 0.4236664018782742, 0.2666676713079777]
# Fold: 1.0
# Iteration: 1
# 0:	learn: 1.1091271	test: 1.1268877	best: 1.1268877 (0)	total: 206ms	remaining: 17m 9s
# 200:	learn: 0.1374238	test: 0.2506987	best: 0.2506987 (200)	total: 32.1s	remaining: 12m 45s
# 400:	learn: 0.0899711	test: 0.2390227	best: 0.2390227 (400)	total: 1m 3s	remaining: 12m 6s
# 600:	learn: 0.0668803	test: 0.2350423	best: 0.2350423 (600)	total: 1m 35s	remaining: 11m 36s
# 800:	learn: 0.0526853	test: 0.2326883	best: 0.2326883 (800)	total: 2m 7s	remaining: 11m 9s
# 1000:	learn: 0.0434885	test: 0.2314304	best: 0.2314304 (1000)	total: 2m 40s	remaining: 10m 40s
# 1200:	learn: 0.0368374	test: 0.2306115	best: 0.2306092 (1197)	total: 3m 13s	remaining: 10m 12s
# 1400:	learn: 0.0320027	test: 0.2302606	best: 0.2302606 (1400)	total: 3m 46s	remaining: 9m 42s
# 1600:	learn: 0.0282425	test: 0.2299646	best: 0.2299617 (1595)	total: 4m 20s	remaining: 9m 13s
# 1800:	learn: 0.0251732	test: 0.2297998	best: 0.2297973 (1797)	total: 4m 54s	remaining: 8m 43s
# 2000:	learn: 0.0225753	test: 0.2296903	best: 0.2296903 (2000)	total: 5m 28s	remaining: 8m 12s
# 2200:	learn: 0.0203832	test: 0.2296034	best: 0.2296020 (2194)	total: 6m 3s	remaining: 7m 42s
# 2400:	learn: 0.0184996	test: 0.2295237	best: 0.2295214 (2398)	total: 6m 37s	remaining: 7m 10s
# 2600:	learn: 0.0167818	test: 0.2295167	best: 0.2295044 (2424)	total: 7m 12s	remaining: 6m 38s
# bestTest = 0.2295044361
# bestIteration = 2424
# Shrink model to first 2425 iterations.
# FOLD RMSE = 0.22950451911252703
# Fold: 2.0
# Iteration: 1
# 0:	learn: 1.1081142	test: 1.1308414	best: 1.1308414 (0)	total: 188ms	remaining: 15m 38s
# 200:	learn: 0.1354758	test: 0.2836474	best: 0.2836474 (200)	total: 32.1s	remaining: 12m 45s
# 400:	learn: 0.0898671	test: 0.2716156	best: 0.2716156 (400)	total: 1m 2s	remaining: 12m
# 600:	learn: 0.0664294	test: 0.2667666	best: 0.2667666 (600)	total: 1m 34s	remaining: 11m 29s
# 800:	learn: 0.0513967	test: 0.2643482	best: 0.2643419 (792)	total: 2m 6s	remaining: 11m 3s
# 1000:	learn: 0.0421766	test: 0.2629100	best: 0.2629071 (998)	total: 2m 39s	remaining: 10m 36s
# 1200:	learn: 0.0358838	test: 0.2620175	best: 0.2620175 (1200)	total: 3m 12s	remaining: 10m 8s
# 1400:	learn: 0.0313294	test: 0.2616701	best: 0.2616701 (1400)	total: 3m 45s	remaining: 9m 39s
# 1600:	learn: 0.0276145	test: 0.2614418	best: 0.2614418 (1600)	total: 4m 19s	remaining: 9m 10s
# 1800:	learn: 0.0246466	test: 0.2611918	best: 0.2611918 (1800)	total: 4m 53s	remaining: 8m 40s
# 2000:	learn: 0.0221791	test: 0.2610245	best: 0.2610245 (2000)	total: 5m 26s	remaining: 8m 10s
# 2200:	learn: 0.0199874	test: 0.2609391	best: 0.2609390 (2199)	total: 6m 1s	remaining: 7m 39s
# 2400:	learn: 0.0180775	test: 0.2608429	best: 0.2608421 (2399)	total: 6m 35s	remaining: 7m 8s
# 2600:	learn: 0.0164156	test: 0.2607857	best: 0.2607796 (2596)	total: 7m 10s	remaining: 6m 36s
# 2800:	learn: 0.0150095	test: 0.2607560	best: 0.2607548 (2799)	total: 7m 44s	remaining: 6m 4s
# 3000:	learn: 0.0136909	test: 0.2607078	best: 0.2607074 (2980)	total: 8m 20s	remaining: 5m 33s
# 3200:	learn: 0.0125299	test: 0.2606721	best: 0.2606721 (3200)	total: 8m 55s	remaining: 5m
# 3400:	learn: 0.0115045	test: 0.2606449	best: 0.2606418 (3381)	total: 9m 30s	remaining: 4m 28s
# 3600:	learn: 0.0105736	test: 0.2606250	best: 0.2606242 (3581)	total: 10m 4s	remaining: 3m 55s
# 3800:	learn: 0.0097022	test: 0.2605977	best: 0.2605977 (3800)	total: 10m 40s	remaining: 3m 21s
# 4000:	learn: 0.0089322	test: 0.2605871	best: 0.2605856 (3958)	total: 11m 15s	remaining: 2m 48s
# 4200:	learn: 0.0082102	test: 0.2605838	best: 0.2605804 (4181)	total: 11m 50s	remaining: 2m 15s
# 4400:	learn: 0.0075669	test: 0.2605816	best: 0.2605773 (4330)	total: 12m 25s	remaining: 1m 41s
# bestTest = 0.2605773415
# bestIteration = 4330
# Shrink model to first 4331 iterations.
# FOLD RMSE = 0.2605772747810745
# Fold: 3.0
# Iteration: 1
# 0:	learn: 1.0964410	test: 1.1716996	best: 1.1716996 (0)	total: 182ms	remaining: 15m 11s
# 200:	learn: 0.1392481	test: 0.2570464	best: 0.2570464 (200)	total: 32.1s	remaining: 12m 45s
# 400:	learn: 0.0929874	test: 0.2470032	best: 0.2469008 (396)	total: 1m 3s	remaining: 12m 4s
# 600:	learn: 0.0683703	test: 0.2424963	best: 0.2424963 (600)	total: 1m 34s	remaining: 11m 34s
# 800:	learn: 0.0538453	test: 0.2401840	best: 0.2401840 (800)	total: 2m 7s	remaining: 11m 5s
# 1000:	learn: 0.0444228	test: 0.2389536	best: 0.2389518 (999)	total: 2m 39s	remaining: 10m 37s
# 1200:	learn: 0.0376165	test: 0.2381401	best: 0.2381401 (1200)	total: 3m 12s	remaining: 10m 10s
# 1400:	learn: 0.0327772	test: 0.2377700	best: 0.2377665 (1399)	total: 3m 46s	remaining: 9m 41s
# 1600:	learn: 0.0288766	test: 0.2374583	best: 0.2374570 (1588)	total: 4m 20s	remaining: 9m 12s
# 1800:	learn: 0.0256975	test: 0.2372505	best: 0.2372493 (1799)	total: 4m 54s	remaining: 8m 43s
# 2000:	learn: 0.0230166	test: 0.2370538	best: 0.2370538 (2000)	total: 5m 28s	remaining: 8m 12s
# 2200:	learn: 0.0208633	test: 0.2369379	best: 0.2369356 (2199)	total: 6m 3s	remaining: 7m 41s
# 2400:	learn: 0.0188874	test: 0.2368375	best: 0.2368370 (2397)	total: 6m 37s	remaining: 7m 10s
# 2600:	learn: 0.0171622	test: 0.2367790	best: 0.2367790 (2600)	total: 7m 12s	remaining: 6m 38s
# 2800:	learn: 0.0156402	test: 0.2367232	best: 0.2367214 (2797)	total: 7m 46s	remaining: 6m 6s
# 3000:	learn: 0.0143077	test: 0.2366566	best: 0.2366560 (2999)	total: 8m 21s	remaining: 5m 34s
# 3200:	learn: 0.0131234	test: 0.2366424	best: 0.2366368 (3166)	total: 8m 56s	remaining: 5m 1s
# 3400:	learn: 0.0120072	test: 0.2366125	best: 0.2366125 (3400)	total: 9m 31s	remaining: 4m 28s
# 3600:	learn: 0.0110212	test: 0.2365895	best: 0.2365895 (3600)	total: 10m 6s	remaining: 3m 55s
# 3800:	learn: 0.0101292	test: 0.2365609	best: 0.2365606 (3796)	total: 10m 41s	remaining: 3m 22s
# 4000:	learn: 0.0093436	test: 0.2365594	best: 0.2365568 (3899)	total: 11m 16s	remaining: 2m 48s
# 4200:	learn: 0.0086231	test: 0.2365431	best: 0.2365430 (4199)	total: 11m 51s	remaining: 2m 15s
# 4400:	learn: 0.0079302	test: 0.2365316	best: 0.2365308 (4395)	total: 12m 26s	remaining: 1m 41s
# 4600:	learn: 0.0073242	test: 0.2365262	best: 0.2365246 (4578)	total: 13m 2s	remaining: 1m 7s
# bestTest = 0.2365245841
# bestIteration = 4578
# Shrink model to first 4579 iterations.
# FOLD RMSE = 0.23652451906848596
# Fold: 4.0
# Iteration: 1
# 0:	learn: 1.1377608	test: 1.0024968	best: 1.0024968 (0)	total: 176ms	remaining: 14m 41s
# 200:	learn: 0.1316260	test: 0.2874077	best: 0.2874037 (199)	total: 32.7s	remaining: 13m
# 400:	learn: 0.0875414	test: 0.2800466	best: 0.2800335 (399)	total: 1m 4s	remaining: 12m 16s
# 600:	learn: 0.0651489	test: 0.2767760	best: 0.2767760 (600)	total: 1m 36s	remaining: 11m 44s
# 800:	learn: 0.0518130	test: 0.2751334	best: 0.2751307 (799)	total: 2m 8s	remaining: 11m 14s
# 1000:	learn: 0.0427196	test: 0.2742982	best: 0.2742982 (1000)	total: 2m 41s	remaining: 10m 45s
# 1200:	learn: 0.0363871	test: 0.2736443	best: 0.2736415 (1198)	total: 3m 14s	remaining: 10m 16s
# 1400:	learn: 0.0316931	test: 0.2734531	best: 0.2734335 (1396)	total: 3m 48s	remaining: 9m 45s
# 1600:	learn: 0.0279402	test: 0.2732238	best: 0.2732238 (1600)	total: 4m 22s	remaining: 9m 17s
# 1800:	learn: 0.0250065	test: 0.2730319	best: 0.2730319 (1800)	total: 4m 56s	remaining: 8m 46s
# 2000:	learn: 0.0224642	test: 0.2729341	best: 0.2729259 (1971)	total: 5m 31s	remaining: 8m 16s
# 2200:	learn: 0.0203523	test: 0.2728624	best: 0.2728571 (2193)	total: 6m 5s	remaining: 7m 44s
# 2400:	learn: 0.0184710	test: 0.2728143	best: 0.2728143 (2400)	total: 6m 39s	remaining: 7m 12s
# 2600:	learn: 0.0168135	test: 0.2727664	best: 0.2727646 (2587)	total: 7m 14s	remaining: 6m 40s
# 2800:	learn: 0.0153452	test: 0.2727435	best: 0.2727208 (2723)	total: 7m 49s	remaining: 6m 8s
# bestTest = 0.2727207849
# bestIteration = 2723
# Shrink model to first 2724 iterations.
# FOLD RMSE = 0.2727207796102726
# Fold: 5.0
# Iteration: 1
# 0:	learn: 1.1082181	test: 1.1264976	best: 1.1264976 (0)	total: 200ms	remaining: 16m 38s
# 200:	learn: 0.1356198	test: 0.2834183	best: 0.2834183 (200)	total: 31.7s	remaining: 12m 37s
# 400:	learn: 0.0889654	test: 0.2731488	best: 0.2731488 (400)	total: 1m 2s	remaining: 11m 59s
# 600:	learn: 0.0659681	test: 0.2696746	best: 0.2696559 (581)	total: 1m 34s	remaining: 11m 29s
# 800:	learn: 0.0521456	test: 0.2681981	best: 0.2681981 (800)	total: 2m 6s	remaining: 11m 1s
# 1000:	learn: 0.0428697	test: 0.2677522	best: 0.2677313 (999)	total: 2m 38s	remaining: 10m 34s
# 1200:	learn: 0.0364774	test: 0.2673477	best: 0.2673477 (1200)	total: 3m 11s	remaining: 10m 6s
# 1400:	learn: 0.0319690	test: 0.2672095	best: 0.2672084 (1314)	total: 3m 44s	remaining: 9m 37s
# 1600:	learn: 0.0282350	test: 0.2670403	best: 0.2670256 (1581)	total: 4m 18s	remaining: 9m 8s
# 1800:	learn: 0.0252055	test: 0.2669262	best: 0.2669210 (1799)	total: 4m 51s	remaining: 8m 38s
# 2000:	learn: 0.0226187	test: 0.2669134	best: 0.2668662 (1936)	total: 5m 25s	remaining: 8m 7s
# 2200:	learn: 0.0205029	test: 0.2668294	best: 0.2668280 (2195)	total: 5m 58s	remaining: 7m 36s
# 2400:	learn: 0.0185365	test: 0.2667770	best: 0.2667761 (2395)	total: 6m 32s	remaining: 7m 5s
# 2600:	learn: 0.0168583	test: 0.2667584	best: 0.2667391 (2565)	total: 7m 6s	remaining: 6m 33s
# 2800:	learn: 0.0153679	test: 0.2667157	best: 0.2667126 (2796)	total: 7m 40s	remaining: 6m 1s
# 3000:	learn: 0.0141152	test: 0.2666990	best: 0.2666859 (2967)	total: 8m 14s	remaining: 5m 29s
# bestTest = 0.2666858914
# bestIteration = 2967
# Shrink model to first 2968 iterations.
# FOLD RMSE = 0.26668585332456146
# ############################################################
# East - MEAN RMSE = 0.2532025891793843
# East - OOF RMSE = 0.253777072894229
# [0.22950451911252703, 0.2605772747810745, 0.23652451906848596, 0.2727207796102726, 0.26668585332456146]
# CPU times: user 2h 9min 55s, sys: 39min 39s, total: 2h 49min 35s
# Wall time: 1h 41min 23s

# %%
all_preds = np.concatenate([north_oof_preds, east_oof_preds])
all_target = np.concatenate([train.North, train.East])

# %%
print("ALL - OOF RMSE = {}".format(np.sqrt(mean_squared_error(all_target, all_preds))))
# Out:
# ALL - OOF RMSE = 0.27627081098725154

# %%
sub_oof = pd.DataFrame({
    'Filename': train.Filename,
    'oof_north': north_oof_preds,
    'oof_east': east_oof_preds
})

sub_oof.to_csv('oof_cat_seq_001.csv', index=False)

# %%
sub_north_test = pd.DataFrame({
    'Id': test.Filename,
    'Predicted': north_test_preds
})

sub_east_test = pd.DataFrame({
    'Id': test.Filename,
    'Predicted': east_test_preds
})

# %%
sub_north_test.Id = sub_north_test['Id'].astype(str) + ':North'
sub_east_test.Id  = sub_east_test['Id'].astype(str) + ':East'

sub_all_test = pd.concat([sub_north_test, sub_east_test])

# %%
sub_all_test[['Id', 'Predicted']].to_csv('sub_cat_seq_001.csv', index=False)

# %%
sub_all_test
# Out:
#                                                Id  Predicted
# 0      0f57a863af3b7e5bf59a94319a408ff7.jpg:North  -0.265378
# 1      b7d4e3a6acb3b956d8b09416958e8892.jpg:North  -0.423045
# 2      9a1bd630a47dabafa6f4cab7338d01df.jpg:North  -0.514241
# 3      3f6ebf8aef0f352720bc0cb534d878b6.jpg:North  -0.540555
# 4      7e810f05bd88ff0f86dce7116b9fa527.jpg:North  -0.570844
# ...                                           ...        ...
# 55026   fc65c23ae61ce2c6fdbc637a8296d1d7.jpg:East   0.880922
# 55027   fc6c0d99ec42bad5e2d5fbb1e71c5a50.jpg:East   1.159392
# 55028   fdbb732633c6a3d32a67fc56edc7cde4.jpg:East  -0.257620
# 55029   feac1b902c7487dcbdf298bd4be75690.jpg:East  -0.425460
# 55030   ff76ffce183c11f84489bbd0a34a2fcf.jpg:East  -1.253009
#
# [110062 rows x 2 columns]
