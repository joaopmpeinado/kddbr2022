# %%
import os
import pandas as pd
import numpy as np
import xgboost as xgb
from lightgbm.callback import early_stopping
from sklearn.model_selection import KFold, GroupKFold
from tqdm import tqdm
from sklearn.metrics import mean_squared_error
import warnings

import math
# Out:
# <style type='text/css'>
# .datatable table.frame { margin-bottom: 0; }
# .datatable table.frame thead { border-bottom: none; }
# .datatable table.frame tr.coltypes td {  color: #FFFFFF;  line-height: 6px;  padding: 0 0.5em;}
# .datatable .bool    { background: #DDDD99; }
# .datatable .object  { background: #565656; }
# .datatable .int     { background: #5D9E5D; }
# .datatable .float   { background: #4040CC; }
# .datatable .str     { background: #CC4040; }
# .datatable .time    { background: #40CC40; }
# .datatable .row_index {  background: var(--jp-border-color3);  border-right: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  font-size: 9px;}
# .datatable .frame tbody td { text-align: left; }
# .datatable .frame tr.coltypes .row_index {  background: var(--jp-border-color0);}
# .datatable th:nth-child(2) { padding-left: 12px; }
# .datatable .hellipsis {  color: var(--jp-cell-editor-border-color);}
# .datatable .vellipsis {  background: var(--jp-layout-color0);  color: var(--jp-cell-editor-border-color);}
# .datatable .na {  color: var(--jp-cell-editor-border-color);  font-size: 80%;}
# .datatable .sp {  opacity: 0.25;}
# .datatable .footer { font-size: 9px; }
# .datatable .frame_dimensions {  background: var(--jp-border-color3);  border-top: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  display: inline-block;  opacity: 0.6;  padding: 1px 10px 1px 5px;}
# </style>

# %%
pd.set_option('display.width', 1000)
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
warnings.filterwarnings('ignore')

path = os.getcwd()

# %%
train = pd.read_csv('../input/kddbr2022apk/train_sequence_fold.csv')
test = pd.read_csv('../input/kddbr2022apk/test_sequence.csv')
df = pd.concat([train, test])

features_1 = pd.read_csv('../input/kddbr2022apk/complete_04.csv')
features_1 = features_1[["Filename","w_std","w_mean","w_median","w_min","w_max","w_var","n_std","n_mean","n_median","n_min","n_max","n_var","d_std","d_mean","d_median","d_min","d_max","d_var"]]
features_1.columns = ["Filename","_w_std","_w_mean","_w_median","_w_min","_w_max","_w_var","_n_std","_n_mean","_n_median","_n_min","_n_max","_n_var","_d_std","_d_mean","_d_median","_d_min","_d_max","_d_var"]
features_2 = pd.read_csv('../input/kddbr2022apk/complete_05.csv')
features_3 = pd.read_csv('../input/kddbr2022apk/complete_06.csv')
features_4 = pd.read_csv('../input/kddbr2022apk/complete_12.csv')

features = pd.merge(features_1, features_2, on='Filename', how='left')
features = pd.merge(features, features_3, on='Filename', how='left')


mario_features_tr = pd.read_csv('../input/kddbr2022apk/mario_train_vec_v1.csv')
mario_features_ts = pd.read_csv('../input/kddbr2022apk/mario_test_vec_v1.csv')

mario_features = pd.concat([mario_features_tr, mario_features_ts])
mario_features2 = pd.read_csv('../input/kddbr2022apk/vecs_v3_fe.csv')

# %%
df = pd.merge(df, features, on='Filename', how='left')
df = pd.merge(df, mario_features, on='Filename', how='left')
df = pd.merge(df, mario_features2, on='Filename', how='left')
df = pd.merge(df, features_4, on='Filename', how='left')

df = df.sort_values(by=['run_id', 'run_seq_id']).reset_index(drop=True)

# %%
import gc
del features, mario_features, mario_features2, features_4, features_2, features_3, features_1
gc.collect()
# Out:
# 901

# %%
df['sqrt_altitude'] = np.sqrt(df['Altitude'])
df['sqrt_delta'] = np.sqrt(df['Delta'])
df['sqrt_altitude_delta'] = np.sqrt(df['Altitude'] + df['Delta'])

df['pow2_altitude'] = (df['Altitude'] ** 2)
df['pow2_delta'] = (df['Delta'] ** 2)
df['pow2_altitude_delta'] = (df['Altitude'] + df['Delta']) ** 2

df['log_Altitude'] = np.log(df['Altitude'])
df['log_Delta'] = np.log(df['Delta'])
df['log_base_05_n_mean'] = np.log(df['base_05_n_mean'])

df['pow13_Altitude'] = df['Altitude'] ** (1/3)
df['pow13_Delta'] = df['Delta'] ** (1/3)
df['pow13_base_05_n_mean'] = df['base_05_n_mean'] ** (1/3)

tgt_columns = [
    'Delta', 'Altitude', 'log_base_05_n_mean', 'pow13_base_05_n_mean',
    'base_05_n_mean', '_n_mean', 'base_05_f05_H_1', 'base_05_n_median', 'base_05_n_max', 'base_05_n_min', 'base_05_f05_H_4', 'x', 'base_05_f05_H_25', 'base_05_f05_H_7', 'x_mean', 'x1_mean', 'x2_mean',
    'base_05_w_mean', '_w_mean', 'base_05_f05_W_21', 'base_05_w_median', 'base_05_w_max', 'base_05_w_min', 'base_05_f05_W_18', 'y', 'base_05_f05_W_6', 'base_05_f05_W_0', 'y_mean', 'y1_mean', 'y2_mean',
    'base_06_n_mean', 'base_06_f06_H_1', 'base_06_n_median', 'base_06_n_max',
    'base_06_w_mean', 'base_06_f06_W_21', 'base_06_w_median', 'base_06_w_max',
    'base_12_x', 'base_12_y', 'base_12_distance'
]

seq_win = [2,3,5,10,15,25,30,50,75]
nxt_sft_win = [1,2,3,4,5,10,15]

for col in tqdm(tgt_columns):
    for win in nxt_sft_win:
        df['shift'+str(win)+'_'+col] = df.groupby('run_id')[col].shift(win).reset_index(0,drop=True)
        df['next'+str(win)+'_'+col] = df.groupby('run_id')[col].shift(-win).reset_index(0,drop=True)
        df['seq_diff_last'+str(win)+'_'+col] = df.groupby('run_id')[col].diff(win).reset_index(0,drop=True)
        df['seq_diff_next'+str(win)+'_'+col] = df.groupby('run_id')[col].diff(-win).reset_index(0,drop=True)
    
    for win in seq_win:
        df['seq_avg_w'+str(win)+'_'+col] = df.groupby('run_id')[col].rolling(win).mean().reset_index(0,drop=True)
        df['seq_std_w'+str(win)+'_'+col] = df.groupby('run_id')[col].rolling(win).std().reset_index(0,drop=True)
        df['seq_max_w'+str(win)+'_'+col] = df.groupby('run_id')[col].rolling(win).max().reset_index(0,drop=True)
        df['seq_min_w'+str(win)+'_'+col] = df.groupby('run_id')[col].rolling(win).min().reset_index(0,drop=True)
    
    
    df['seq_div_last1_'+col] = df[col] / df['shift1_'+col]
    df['seq_div_next1_'+col] = df[col] / df['next1_'+col]
    df['seq_div_last2_'+col] = df[col] / df['shift2_'+col]
    df['seq_div_next2_'+col] = df[col] / df['next2_'+col]
    df['seq_div_last3_'+col] = df[col] / df['shift3_'+col]
    df['seq_div_next3_'+col] = df[col] / df['next3_'+col]
    
    df['seq_min_'+col] = df.groupby('run_id')[col].transform('min')
    df['seq_max_'+col] = df.groupby('run_id')[col].transform('max')
    df['seq_std_'+col] = df.groupby('run_id')[col].transform('std')
    df['seq_avg_'+col] = df.groupby('run_id')[col].transform('mean')

df['r_vetorial_now'] = (df['base_05_n_mean'] ** 2) + (df['base_05_w_mean'] ** 2)
df['shift_r_vetorial'] = (df['shift1_base_05_n_mean'] ** 2) + (df['shift1_base_05_w_mean'] ** 2)
df['shift2_r_vetorial'] = (df['shift2_base_05_n_mean'] ** 2) + (df['shift2_base_05_w_mean'] ** 2)
df['next_r_vetorial'] = (df['next1_base_05_n_mean'] ** 2) + (df['next1_base_05_w_mean'] ** 2)
df['next2_r_vetorial'] = (df['next2_base_05_n_mean'] ** 2) + (df['next2_base_05_w_mean'] ** 2)
df['avg_shift_r_vet'] = (df['r_vetorial_now'] + df['shift_r_vetorial'] + df['shift2_r_vetorial']) / 3
df['avg_next_r_vet'] = (df['r_vetorial_now'] + df['next_r_vetorial'] + df['next2_r_vetorial']) / 3
df['avg_all_r_vet'] = (df['r_vetorial_now'] + df['next_r_vetorial'] + df['next2_r_vetorial'] + df['shift_r_vetorial'] + df['shift2_r_vetorial']) / 5

df['div_r_next2_next'] = df['next2_r_vetorial'] / df['next_r_vetorial']
df['div_r_next_now'] = df['next_r_vetorial'] / df['r_vetorial_now']
df['div_r_now_shift'] = df['r_vetorial_now'] / df['shift_r_vetorial']
df['div_r_shift1_shift2'] = df['shift_r_vetorial'] / df['shift2_r_vetorial']
df['avg_div_r'] = (df['div_r_next2_next'] + df['div_r_next_now'] + df['div_r_now_shift'] + df['div_r_shift1_shift2']) / 4
# Out:
# 100%|██████████| 41/41 [05:33<00:00,  8.13s/it]

# %%
print(df.shape)
# Out:
# (146262, 3233)

# %%
train = df.loc[~df.North.isnull(), :].sort_values(by=['run_id', 'run_seq_id']).reset_index(drop=True)
test = df.loc[df.North.isnull(), :].sort_values(by=['run_id', 'run_seq_id']).reset_index(drop=True)

# %%
import gc
del df
gc.collect()
# Out:
# 23

# %%
train_columns = [col for col in train.columns if col not in ['Filename', 'North', 'East', 'fold', 'run_id', 'run_seq_id']]

# %%
n_folds = 5

north_oof_preds = np.zeros(len(train))
east_oof_preds = np.zeros(len(train))

north_test_preds = np.zeros(len(test))
east_test_preds = np.zeros(len(test))

targets = ['North', 'East']

# %%
train = train.replace([np.inf, -np.inf], np.nan)
#trn_x = trn_x.fillna(-999)
test = test.replace([np.inf, -np.inf], np.nan)

# %%
# %%time
for target in targets:
    y = train[target]
    oof_preds = np.zeros(len(train))
    test_preds_fold = np.zeros(len(test))
    score_folds  = []

    # folds = GroupKFold(n_splits=n_folds)
    # for fold_, (trn_, val_) in enumerate(folds.split(y, y, train.run_id)):
    for fold_ in train.fold.sort_values().unique():
        print("Fold: {}".format(fold_))

        trn_ = train.loc[train.fold != fold_].index
        val_ = train.loc[train.fold == fold_].index

        trn_x, trn_y = train.loc[trn_, train_columns], y.loc[trn_]
        val_x, val_y = train.loc[val_, train_columns], y.loc[val_]
        
        dtrain = xgb.DMatrix(trn_x, trn_y)
        dvalid = xgb.DMatrix(val_x, val_y)
        
        watchlist = [(dtrain, 'train'), (dvalid, 'valid')]
        
        params = {
          'objective': "reg:squarederror", #"reg:logistic",
          'booster': "gbtree",
          'eval_metric': 'rmse', 
          'colsample_bytree': 0.85,
          'subsample': 0.85,
          'eta': 0.1,
          'max_depth': 5,
          'min_child_weight': 64, 
          'max_bin': 32,
          'nthread':-1,
          'seed': 99,
          'tree_method': 'gpu_hist'
        }
        
        execs = 1
        preds = np.zeros(len(val_x))
        test_preds_exec = np.zeros(len(test))
        
        for p in range(0,execs):
            print("Iteration: {}".format(p+1))
            params['seed'] += p
            model = xgb.train(params, dtrain, 
                               10000, watchlist, 
                               maximize=False, 
                               early_stopping_rounds = 200, 
                               verbose_eval=200)
                            #early_stopping_rounds = 1000)
            del dtrain, dvalid, trn_x
            gc.collect()
            preds += ((model.predict(xgb.DMatrix(val_x))) / execs)
            test_preds_exec += ((model.predict(xgb.DMatrix(test[train_columns]))) / execs)

        test_preds_fold += (test_preds_exec / n_folds)
        oof_preds[val_] = preds
        score_folds.append(np.sqrt(mean_squared_error(val_y, preds)))
        print("FOLD RMSE = {}".format(np.sqrt(mean_squared_error(val_y, preds))))
        del model, val_x
        gc.collect()

    print("############################################################")
    print("{} - MEAN RMSE = {}".format(target, np.mean(score_folds)))
    print("{} - OOF RMSE = {}".format(target, np.sqrt(mean_squared_error(y, oof_preds))))
    print(score_folds)

    if target == 'North':
        north_oof_preds = oof_preds
        north_test_preds = test_preds_fold
    else:
        east_oof_preds = oof_preds
        east_test_preds = test_preds_fold
# Out:
# Fold: 1.0
# Iteration: 1
# [0]	train-rmse:1.17924	valid-rmse:1.17055
# [200]	train-rmse:0.17961	valid-rmse:0.26599
# [400]	train-rmse:0.14274	valid-rmse:0.25890
# [600]	train-rmse:0.11840	valid-rmse:0.25686
# [800]	train-rmse:0.10243	valid-rmse:0.25524
# [1000]	train-rmse:0.08967	valid-rmse:0.25357
# [1200]	train-rmse:0.07983	valid-rmse:0.25244
# [1400]	train-rmse:0.07160	valid-rmse:0.25194
# [1600]	train-rmse:0.06499	valid-rmse:0.25143
# [1800]	train-rmse:0.05928	valid-rmse:0.25127
# [1863]	train-rmse:0.05770	valid-rmse:0.25122
# FOLD RMSE = 0.25121576125201
# Fold: 2.0
# Iteration: 1
# [0]	train-rmse:1.16508	valid-rmse:1.23166
# [200]	train-rmse:0.16321	valid-rmse:0.30983
# [400]	train-rmse:0.12454	valid-rmse:0.30499
# [600]	train-rmse:0.10137	valid-rmse:0.30221
# [800]	train-rmse:0.08573	valid-rmse:0.30015
# [1000]	train-rmse:0.07358	valid-rmse:0.29943
# [1200]	train-rmse:0.06396	valid-rmse:0.29839
# [1400]	train-rmse:0.05659	valid-rmse:0.29833
# [1600]	train-rmse:0.05031	valid-rmse:0.29775
# [1800]	train-rmse:0.04552	valid-rmse:0.29707
# [2000]	train-rmse:0.04155	valid-rmse:0.29662
# [2200]	train-rmse:0.03807	valid-rmse:0.29636
# [2400]	train-rmse:0.03513	valid-rmse:0.29627
# [2600]	train-rmse:0.03272	valid-rmse:0.29624
# [2800]	train-rmse:0.03047	valid-rmse:0.29603
# [3000]	train-rmse:0.02842	valid-rmse:0.29588
# [3200]	train-rmse:0.02666	valid-rmse:0.29579
# [3355]	train-rmse:0.02526	valid-rmse:0.29581
# FOLD RMSE = 0.29581209133892755
# Fold: 3.0
# Iteration: 1
# [0]	train-rmse:1.18808	valid-rmse:1.12951
# [200]	train-rmse:0.18246	valid-rmse:0.26471
# [400]	train-rmse:0.14638	valid-rmse:0.26057
# [600]	train-rmse:0.12372	valid-rmse:0.25820
# [800]	train-rmse:0.10698	valid-rmse:0.25743
# [1000]	train-rmse:0.09507	valid-rmse:0.25695
# [1090]	train-rmse:0.09006	valid-rmse:0.25681
# FOLD RMSE = 0.256817841210855
# Fold: 4.0
# Iteration: 1
# [0]	train-rmse:1.17681	valid-rmse:1.17804
# [200]	train-rmse:0.11990	valid-rmse:0.44841
# [400]	train-rmse:0.08832	valid-rmse:0.44483
# [600]	train-rmse:0.07159	valid-rmse:0.44216
# [800]	train-rmse:0.06064	valid-rmse:0.44094
# [1000]	train-rmse:0.05264	valid-rmse:0.44008
# [1200]	train-rmse:0.04694	valid-rmse:0.43974
# [1400]	train-rmse:0.04261	valid-rmse:0.43939
# [1600]	train-rmse:0.03925	valid-rmse:0.43923
# [1800]	train-rmse:0.03628	valid-rmse:0.43917
# [2000]	train-rmse:0.03367	valid-rmse:0.43907
# [2200]	train-rmse:0.03145	valid-rmse:0.43884
# [2400]	train-rmse:0.02944	valid-rmse:0.43882
# [2600]	train-rmse:0.02780	valid-rmse:0.43878
# [2800]	train-rmse:0.02625	valid-rmse:0.43869
# [3000]	train-rmse:0.02488	valid-rmse:0.43864
# [3200]	train-rmse:0.02350	valid-rmse:0.43849
# [3400]	train-rmse:0.02230	valid-rmse:0.43843
# [3600]	train-rmse:0.02117	valid-rmse:0.43841
# [3663]	train-rmse:0.02084	valid-rmse:0.43838
# FOLD RMSE = 0.43837821657010845
# Fold: 5.0
# Iteration: 1
# [0]	train-rmse:1.17801	valid-rmse:1.17848
# [200]	train-rmse:0.17015	valid-rmse:0.28856
# [400]	train-rmse:0.13000	valid-rmse:0.28364
# [600]	train-rmse:0.10598	valid-rmse:0.28074
# [800]	train-rmse:0.08924	valid-rmse:0.27929
# [1000]	train-rmse:0.07649	valid-rmse:0.27889
# [1200]	train-rmse:0.06725	valid-rmse:0.27820
# [1400]	train-rmse:0.05908	valid-rmse:0.27766
# [1600]	train-rmse:0.05263	valid-rmse:0.27721
# [1800]	train-rmse:0.04711	valid-rmse:0.27696
# [1921]	train-rmse:0.04447	valid-rmse:0.27683
# FOLD RMSE = 0.2768272438806506
# ############################################################
# North - MEAN RMSE = 0.30381023085051034
# North - OOF RMSE = 0.31156908633895297
# [0.25121576125201, 0.29581209133892755, 0.256817841210855, 0.43837821657010845, 0.2768272438806506]
# Fold: 1.0
# Iteration: 1
# [0]	train-rmse:1.14663	valid-rmse:1.17285
# [200]	train-rmse:0.12560	valid-rmse:0.24906
# [400]	train-rmse:0.09392	valid-rmse:0.24391
# [600]	train-rmse:0.07658	valid-rmse:0.24182
# [800]	train-rmse:0.06507	valid-rmse:0.24031
# [1000]	train-rmse:0.05683	valid-rmse:0.23967
# [1200]	train-rmse:0.05054	valid-rmse:0.23906
# [1400]	train-rmse:0.04532	valid-rmse:0.23849
# [1600]	train-rmse:0.04118	valid-rmse:0.23830
# [1800]	train-rmse:0.03763	valid-rmse:0.23798
# [2000]	train-rmse:0.03451	valid-rmse:0.23795
# [2200]	train-rmse:0.03187	valid-rmse:0.23772
# [2400]	train-rmse:0.02956	valid-rmse:0.23766
# [2600]	train-rmse:0.02756	valid-rmse:0.23756
# [2800]	train-rmse:0.02578	valid-rmse:0.23745
# [3000]	train-rmse:0.02415	valid-rmse:0.23740
# [3091]	train-rmse:0.02343	valid-rmse:0.23738
# FOLD RMSE = 0.23737705151023553
# Fold: 2.0
# Iteration: 1
# [0]	train-rmse:1.14605	valid-rmse:1.17311
# [200]	train-rmse:0.12359	valid-rmse:0.26960
# [400]	train-rmse:0.08963	valid-rmse:0.26309
# [600]	train-rmse:0.07161	valid-rmse:0.26082
# [800]	train-rmse:0.06033	valid-rmse:0.25976
# [1000]	train-rmse:0.05248	valid-rmse:0.25939
# [1200]	train-rmse:0.04661	valid-rmse:0.25917
# [1400]	train-rmse:0.04210	valid-rmse:0.25938
# [1460]	train-rmse:0.04082	valid-rmse:0.25932
# FOLD RMSE = 0.2593153854670846
# Fold: 3.0
# Iteration: 1
# [0]	train-rmse:1.13286	valid-rmse:1.23068
# [200]	train-rmse:0.13213	valid-rmse:0.25265
# [400]	train-rmse:0.09689	valid-rmse:0.24703
# [600]	train-rmse:0.07819	valid-rmse:0.24567
# [800]	train-rmse:0.06642	valid-rmse:0.24475
# [1000]	train-rmse:0.05749	valid-rmse:0.24385
# [1200]	train-rmse:0.05087	valid-rmse:0.24352
# [1400]	train-rmse:0.04553	valid-rmse:0.24315
# [1600]	train-rmse:0.04100	valid-rmse:0.24285
# [1800]	train-rmse:0.03739	valid-rmse:0.24260
# [2000]	train-rmse:0.03430	valid-rmse:0.24248
# [2200]	train-rmse:0.03165	valid-rmse:0.24237
# [2400]	train-rmse:0.02921	valid-rmse:0.24232
# [2600]	train-rmse:0.02722	valid-rmse:0.24222
# [2800]	train-rmse:0.02546	valid-rmse:0.24218
# [2992]	train-rmse:0.02390	valid-rmse:0.24220
# FOLD RMSE = 0.24220396410983167
# Fold: 4.0
# Iteration: 1
# [0]	train-rmse:1.17450	valid-rmse:1.04890
# [200]	train-rmse:0.11899	valid-rmse:0.27979
# [400]	train-rmse:0.08735	valid-rmse:0.27434
# [600]	train-rmse:0.07057	valid-rmse:0.27379
# [693]	train-rmse:0.06541	valid-rmse:0.27389
# FOLD RMSE = 0.2738927561163762
# Fold: 5.0
# Iteration: 1
# [0]	train-rmse:1.15700	valid-rmse:1.13196
# [200]	train-rmse:0.12782	valid-rmse:0.29351
# [400]	train-rmse:0.09276	valid-rmse:0.28460
# [600]	train-rmse:0.07518	valid-rmse:0.28207
# [800]	train-rmse:0.06306	valid-rmse:0.28078
# [1000]	train-rmse:0.05463	valid-rmse:0.27988
# [1200]	train-rmse:0.04814	valid-rmse:0.27959
# [1400]	train-rmse:0.04312	valid-rmse:0.27932
# [1600]	train-rmse:0.03915	valid-rmse:0.27921
# [1634]	train-rmse:0.03850	valid-rmse:0.27920
# FOLD RMSE = 0.27919882531744583
# ############################################################
# East - MEAN RMSE = 0.2583975965041948
# East - OOF RMSE = 0.2589300035170877
# [0.23737705151023553, 0.2593153854670846, 0.24220396410983167, 0.2738927561163762, 0.27919882531744583]
# CPU times: user 28min 28s, sys: 49.2 s, total: 29min 17s
# Wall time: 26min 20s

# %%
all_preds = np.concatenate([north_oof_preds, east_oof_preds])
all_target = np.concatenate([train.North, train.East])

# %%
print("ALL - OOF RMSE = {}".format(np.sqrt(mean_squared_error(all_target, all_preds))))
# Out:
# ALL - OOF RMSE = 0.28646120355420646

# %%
sub_oof = pd.DataFrame({
    'Filename': train.Filename,
    'oof_north': north_oof_preds,
    'oof_east': east_oof_preds
})

sub_oof.to_csv('oof_xgb_seq_009.csv', index=False)

# %%
sub_north_test = pd.DataFrame({
    'Id': test.Filename,
    'Predicted': north_test_preds
})

sub_east_test = pd.DataFrame({
    'Id': test.Filename,
    'Predicted': east_test_preds
})

# %%
sub_north_test.Id = sub_north_test['Id'].astype(str) + ':North'
sub_east_test.Id  = sub_east_test['Id'].astype(str) + ':East'

sub_all_test = pd.concat([sub_north_test, sub_east_test])

# %%
sub_all_test[['Id', 'Predicted']].to_csv('sub_xgb_seq_009.csv', index=False)

# %%
sub_all_test
# Out:
#                                                Id  Predicted
# 0      0f57a863af3b7e5bf59a94319a408ff7.jpg:North  -0.279862
# 1      b7d4e3a6acb3b956d8b09416958e8892.jpg:North  -0.459881
# 2      9a1bd630a47dabafa6f4cab7338d01df.jpg:North  -0.544537
# 3      3f6ebf8aef0f352720bc0cb534d878b6.jpg:North  -0.582841
# 4      7e810f05bd88ff0f86dce7116b9fa527.jpg:North  -0.612460
# ...                                           ...        ...
# 55026   fc65c23ae61ce2c6fdbc637a8296d1d7.jpg:East   1.412073
# 55027   fc6c0d99ec42bad5e2d5fbb1e71c5a50.jpg:East   1.370221
# 55028   fdbb732633c6a3d32a67fc56edc7cde4.jpg:East  -0.229098
# 55029   feac1b902c7487dcbdf298bd4be75690.jpg:East  -0.246406
# 55030   ff76ffce183c11f84489bbd0a34a2fcf.jpg:East  -1.330009
#
# [110062 rows x 2 columns]
